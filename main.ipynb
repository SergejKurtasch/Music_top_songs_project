# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import urllib.parse

# %% [markdown]
# ### Step 1
# Using the website [https://www.offiziellecharts.de/](https://www.offiziellecharts.de/) and web scraping with the help of BeautifulSoup, I saved the top 100 songs for each year from 2015 to 2022.

# %%
def scrape_year(year):
    """
    This function requests the official charts page for a given year,
    parses the HTML using Beautiful Soup, and returns a DataFrame that
    contains track positions, artist names, and track titles.
    """
    url = f"https://www.offiziellecharts.de/charts/single-jahr/for-date-{year}"
    response = requests.get(url)
    
    if response.status_code != 200:
        print(f"Error loading the page for {year}: HTTP {response.status_code}")
        return pd.DataFrame()
    
    soup = BeautifulSoup(response.text, "html.parser")
    
    # Find all the table rows that contain track information.
    # In this case, it is assumed that the data is within <tr class="drill-down-link">
    rows = soup.find_all("tr", class_="drill-down-link")
    
    data = []
    for row in rows:
        # Extract the track position from <span class="this-week">
        pos_tag = row.find("span", class_="this-week")
        pos = pos_tag.get_text(strip=True) if pos_tag else None

        # Extract the artist name from <span class="info-artist">
        artist_tag = row.find("span", class_="info-artist")
        artist = artist_tag.get_text(strip=True) if artist_tag else None

        # Extract the track title from <span class="info-title">
        title_tag = row.find("span", class_="info-title")
        title = title_tag.get_text(strip=True) if title_tag else None
        
        data.append({"Position": pos, "Artist": artist, "Title": title})
    
    df = pd.DataFrame(data)
    return df

# Dictionary to store DataFrames for each year
yearly_dataframes = {}

# Process the years from 2015 to 2022 (inclusive)
for year in range(2015, 2023):
    print(f"Processing data for {year}...")
    df_year = scrape_year(year)
    yearly_dataframes[year] = df_year
    # Optionally, save the DataFrame to a separate CSV file
    df_year.to_csv(f"charts_{year}.csv", index=False, encoding="utf-8")
    print(f"Data for {year} saved (records found: {len(df_year)}).")
# Out:
# Processing data for 2015...
# Data for 2015 saved (records found: 100).
# Processing data for 2016...
# Data for 2016 saved (records found: 100).
# Processing data for 2017...
# Data for 2017 saved (records found: 100).
# Processing data for 2018...
# Data for 2018 saved (records found: 100).
# Processing data for 2019...
# Data for 2019 saved (records found: 100).
# Processing data for 2020...
# Data for 2020 saved (records found: 100).
# Processing data for 2021...
# Data for 2021 saved (records found: 100).
# Processing data for 2022...
# Data for 2022 saved (records found: 100).

# %%
yearly_dataframes[2015]
# Out:
#    Position                                   Artist  \
# 0         1                                      Omi
# 1         2                         Lost Frequencies
# 2         3       Felix Jaehn feat. Jasmine Thompson
# 3         4                           Ellie Goulding
# 4         5          Major Lazer & DJ Snake feat. MØ
# ..      ...                                      ...
# 95       96                          Pitbull & Ne-Yo
# 96       97                 K.I.Z. feat. Henning May
# 97       98                            Justin Bieber
# 98       99                  Mark Forster feat. Sido
# 99      100  Lilly Wood & The Prick and Robin Schulz
#
#                                Title
# 0    Cheerleader (Felix Jaehn Remix)
# 1                    Are You With Me
# 2     Ain't Nobody (Loves Me Better)
# 3                Love Me Like You Do
# 4                            Lean On
# ..                               ...
# 95                 Time Of Our Lives
# 96         Hurra die Welt geht unter
# 97                     Love Yourself
# 98                         Au revoir
# 99  Prayer In C (Robin Schulz Remix)
#
# [100 rows x 3 columns]

# %%
yearly_dataframes[2022]
# Out:
#    Position                   Artist                       Title
# 0         1       DJ Robin & Schürze                       Layla
# 1         2            Glass Animals                  Heat Waves
# 2         3                  Luciano              Beautiful Girl
# 3         4                    Gayle                     abcdefu
# 4         5               Ed Sheeran                     Shivers
# ..      ...                      ...                         ...
# 95       96    Bonez MC & RAF Camora                 Letztes Mal
# 96       97    Bonez MC / RAF Camora                      Sommer
# 97       98                Chris Rea  Driving Home For Christmas
# 98       99  Alle Farben feat. Kiddo                     Alright
# 99      100             Taylor Swift                   Anti-Hero
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Step 2
# Using the song title and artist’s name, I searched for the MBID (MusicBrainz Identifier) on acousticbrainz.org.

# %%
import requests
import time
import urllib.parse
import pandas as pd

def get_recording_mb(artist, title):
    """
    Search MusicBrainz for a recording using artist and title.
    Returns the MBID of the first result, or None if nothing is found.
    """
    query = f'artist:"{artist}" AND recording:"{title}"'
    url = f"https://musicbrainz.org/ws/2/recording/?query={urllib.parse.quote(query)}&fmt=json"
    headers = {"User-Agent": "YourAppName/1.0 (your_email@example.com)"}
    
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"MusicBrainz search error for '{artist} - {title}': HTTP {response.status_code}")
        return None

    data = response.json()
    recordings = data.get("recordings", [])
    if not recordings:
        print(f"No recording found for '{artist} - {title}'")
        return None

    return recordings[0].get("id")

mbid_yearly = {}

# --- Part 1: Collecting MBIDs for each track ---
for year, df in yearly_dataframes.items():
   
    results = []
    print(f"Processing MBIDs for year {year}...")
    for index, row in df.iterrows():
        artist = row['Artist']
        title = row['Title']
        print(f"Processing track: {artist} - {title}")
        
        # Retrieve MBID via MusicBrainz
        mbid = get_recording_mb(artist, title)
        time.sleep(1)  # Delay to respect MusicBrainz rate limits
        
        # Add MBID to the row data
        new_row = row.to_dict()
        new_row['MBID'] = mbid
        results.append(new_row)
    
    # Create a new DataFrame for the given year with the added MBID column
    new_df = pd.DataFrame(results)
    mbid_yearly[year] = new_df
    
    # Print a summary of successfully retrieved MBIDs
    found_count = new_df['MBID'].notna().sum()
    total_count = len(new_df)
    print(f"Finished processing {year}. Found MBID for {found_count} out of {total_count} tracks.\n")
# Out:
# Processing MBIDs for year 2015...
# Processing track: Omi - Cheerleader (Felix Jaehn Remix)
# Processing track: Lost Frequencies - Are You With Me
# Processing track: Felix Jaehn feat. Jasmine Thompson - Ain't Nobody (Loves Me Better)
# Processing track: Ellie Goulding - Love Me Like You Do
# Processing track: Major Lazer & DJ Snake feat. MØ - Lean On
# Processing track: Sido feat. Andreas Bourani - Astronaut
# Processing track: Adele - Hello
# Processing track: Robin Schulz feat. Francesco Yates - Sugar
# Processing track: Wiz Khalifa feat. Charlie Puth - See You Again
# Processing track: Kygo feat. Conrad - Firestone
# Processing track: Philipp Dittberner & Marv - Wolke 4
# Processing track: Namika - Lieblingsmensch
# Processing track: Sarah Connor - Wie schön du bist
# Processing track: Lost Frequencies feat. Janieck Devy - Reality
# Processing track: Anna Naklab feat. Alle Farben & Younotus - Supergirl
# Processing track: Jason Derulo - Want To Want Me
# Processing track: Gestört aber GeiL & Koby Funk feat. Wincent Weiss - Unter meiner Haut
# Processing track: Ed Sheeran - Photograph
# Processing track: Robin Schulz feat. Ilsey - Headlights
# Processing track: Kygo feat. Parson James - Stole The Show
# Processing track: Madcon feat. Ray Dalton - Don't Worry
# Processing track: Mark Ronson feat. Bruno Mars - Uptown Funk!
# Processing track: Cro - Bye Bye
# Processing track: Glasperlenspiel - Geiles Leben
# Processing track: Rihanna and Kanye West and Paul McCartney - FourFiveSeconds
# Processing track: Joris - Herz über Kopf
# Processing track: MoTrip feat. Lary - So wie du bist
# Processing track: Calvin Harris + Disciples - How Deep Is Your Love
# Processing track: James Newton Howard feat. Jennifer Lawrence - The Hanging Tree
# Processing track: Hozier - Take Me To Church
# Processing track: Martin Solveig & GTA - Intoxicated
# Processing track: Avicii - Waiting For Love
# Processing track: James Bay - Hold Back The River
# Processing track: David Guetta feat. Nicki Minaj & Afrojack - Hey Mama
# Processing track: Walk The Moon - Shut Up + Dance
# No recording found for 'Walk The Moon - Shut Up + Dance'
# Processing track: Mark Forster - Flash mich
# Processing track: Louane - Avenir
# Processing track: Years & Years - King
# Processing track: Feder feat. Lyse - Goodbye
# Processing track: Calvin Harris feat. Ellie Goulding - Outside
# Processing track: Nicky Jam & Enrique Iglesias - El perdón
# Processing track: Justin Bieber - What Do You Mean?
# Processing track: Ed Sheeran - Thinking Out Loud
# Processing track: Adam Lambert - Ghost Town
# Processing track: Kwabs - Walk
# Processing track: Andreas Bourani - Auf anderen Wegen
# Processing track: The Weeknd - Can't Feel My Face
# Processing track: R. City feat. Adam Levine - Locked Away
# Processing track: Fifth Harmony feat. Kid Ink - Worth It
# Processing track: Helene Fischer - Atemlos durch die Nacht
# Processing track: SDP feat. Adel Tawil - Ich will nur dass du weißt
# Processing track: Justin Bieber - Sorry
# Processing track: Philip George - Wish You Were Mine
# Processing track: The Weeknd - The Hills
# Processing track: Felix Jaehn feat. Polina - Book Of Love
# Processing track: Zara Larsson - Lush Life
# Processing track: Flo Rida feat. Sage The Gemini & Lookas - G.D.F.R.
# Processing track: Robin Schulz feat. Jasmine Thompson - Sun Goes Down
# Processing track: Deorro x Chris Brown - Five More Hours
# Processing track: LunchMoney Lewis - Bills
# Processing track: AronChupa - I'm An Albatraoz
# Processing track: Sigala - Easy Love
# Processing track: Echosmith - Cool Kids
# Processing track: John Legend - All Of Me
# Processing track: Charli XCX - Break The Rules
# Processing track: Carly Rae Jepsen - I Really Like You
# Processing track: David Guetta feat. Sam Martin - Dangerous
# Processing track: Meghan Trainor - Lips Are Movin
# Processing track: Lena - Traffic Lights
# Processing track: Matt Simons - Catch & Release (Deepend Remix)
# Processing track: Lena - Wild & Free
# Processing track: Olly Murs feat. Demi Lovato - Up
# Processing track: Chris Brown x Tyga - Ayo
# Processing track: Skrillex & Diplo feat. Justin Bieber - Where Are Ü Now
# Processing track: Flo Rida feat. Robin Thicke & Verdine White - I Don't Like It, I Love It
# Processing track: Andreas Bourani - Auf uns
# Processing track: Charlie Puth feat. Meghan Trainor - Marvin Gaye
# Processing track: Omi - Hula Hoop
# Processing track: Johannes Oerding - Alles brennt
# Processing track: Taylor Swift - Blank Space
# Processing track: Avicii - The Nights
# Processing track: The Avener - Fade Out Lines
# Processing track: David Guetta feat. Emeli Sandé - What I Did For Love
# Processing track: Klingande feat. Broken Back - Riva (Restart The Game)
# Processing track: DJ Snake & AlunaGeorge - You Know You Like It
# Processing track: Ellie Goulding - On My Mind
# Processing track: DJ Antoine feat. Akon - Holiday
# Processing track: Gestört aber GeiL feat. Sebastian Hämer - Ich & du
# Processing track: The Weeknd - Earned It
# Processing track: Mark Forster - Bauch und Kopf
# Processing track: Alvaro Soler - El mismo sol
# Processing track: XOV - Lucifer
# Processing track: Robin Schulz & J.U.D.G.E. - Show Me Love
# Processing track: Calvin Harris feat. Haim - Pray To God
# Processing track: Kelly Clarkson - Heartbeat Song
# Processing track: Pitbull & Ne-Yo - Time Of Our Lives
# Processing track: K.I.Z. feat. Henning May - Hurra die Welt geht unter
# Processing track: Justin Bieber - Love Yourself
# Processing track: Mark Forster feat. Sido - Au revoir
# Processing track: Lilly Wood & The Prick and Robin Schulz - Prayer In C (Robin Schulz Remix)
# Finished processing 2015. Found MBID for 99 out of 100 tracks.
#
# Processing MBIDs for year 2016...
# Processing track: Alan Walker - Faded
# Processing track: Stereoact feat. Kerstin Ott - Die immer lacht
# Processing track: Sia feat. Sean Paul - Cheap Thrills
# Processing track: Imany - Don't Be So Shy (Filatov & Karas Remix)
# Processing track: Drake feat. Wizkid & Kyla - One Dance
# Processing track: Kungs vs. Cookin' On 3 Burners - This Girl
# Processing track: The Chainsmokers feat. Daya - Don't Let Me Down
# Processing track: Twenty One Pilots - Stressed Out
# Processing track: Rag'n'Bone Man - Human
# Processing track: Justin Timberlake - Can't Stop The Feeling!
# Processing track: Mike Posner - I Took A Pill In Ibiza
# Processing track: Justin Bieber - Love Yourself
# Processing track: Jonas Blue feat. Dakota - Fast Car
# Processing track: Disturbed - The Sound Of Silence
# Processing track: Major Lazer feat. Justin Bieber & MØ - Cold Water
# Processing track: DJ Snake feat. Justin Bieber - Let Me Love You
# Processing track: Calvin Harris feat. Rihanna - This Is What You Came For
# Processing track: The Chainsmokers feat. Halsey - Closer
# Processing track: G-Eazy x Bebe Rexha - Me, Myself & I
# Processing track: Jennifer Lopez - Ain't Your Mama
# Processing track: Mark Forster - Wir sind gross
# Processing track: Lukas Graham - 7 Years
# Processing track: Felix Jaehn feat. Alma - Bonfire
# Processing track: Shawn Mendes - Treat You Better
# Processing track: Andreas Gabalier - Hulapalu
# Processing track: Alle Farben feat. Younotus - Please Tell Rosie
# Processing track: Mike Perry feat. Shy Martin - The Ocean
# Processing track: Coldplay - Hymn For The Weekend
# Processing track: Major Lazer feat. Nyla & Fuse ODG - Light It Up (Remix)
# Processing track: Fifth Harmony feat. Ty Dolla $ign - Work From Home
# Processing track: Max Giesinger - 80 Millionen
# Processing track: Desiigner - Panda
# Processing track: Gnash feat. Olivia O'Brien - I Hate U, I Love U
# Processing track: Twenty One Pilots - Heathens
# Processing track: Shawn Mendes - Stitches
# Processing track: DNCE - Cake By The Ocean
# Processing track: Galantis - No Money
# Processing track: Beginner feat. Gzuz & Gentleman - Ahnma
# Processing track: EFF - Stimme
# Processing track: Glasperlenspiel - Geiles Leben
# Processing track: 257ers - Holz
# Processing track: David Guetta feat. Zara Larsson - This One's For You
# Processing track: Rihanna feat. Drake - Work
# Processing track: Sia feat. Kendrick Lamar - The Greatest
# Processing track: Cheat Codes x Kris Kross Amsterdam - Sex
# Processing track: Lil Wayne, Wiz Khalifa & Imagine Dragons feat. Logic, Ty Dolla $ign & X Ambassadors - Sucker For Pain
# No recording found for 'Lil Wayne, Wiz Khalifa & Imagine Dragons feat. Logic, Ty Dolla $ign & X Ambassadors - Sucker For Pain'
# Processing track: Bonez MC & RAF Camora - Palmen aus Plastik
# Processing track: Justin Bieber - Sorry
# Processing track: The Weeknd feat. Daft Punk - Starboy
# Processing track: Jonas Blue feat. JP. Cooper - Perfect Strangers
# Processing track: Alan Walker - Sing Me To Sleep
# Processing track: Matt Simons - Catch & Release (Deepend Remix)
# Processing track: David Guetta, Cedric Gervais & Chris Willis - Would I Lie To You
# Processing track: Zara Larsson - Lush Life
# Processing track: Bonez MC & RAF Camora feat. Maxwell - Ohne mein Team
# Processing track: Topic feat. Nico Santos - Home
# Processing track: Era Istrefi - Bonbon
# Processing track: Calvin Harris - My Way
# Processing track: Clean Bandit feat. Sean Paul & Anne-Marie - Rockabye
# Processing track: Martin Garrix & Bebe Rexha - In The Name Of Love
# Processing track: Elle King - Ex's & Oh's
# Processing track: Enrique Iglesias feat. Wisin - Duele el corazón
# No recording found for 'Enrique Iglesias feat. Wisin - Duele el corazón'
# Processing track: MØ - Final Song
# Processing track: Frans - If I Were Sorry
# Processing track: Drake feat. Rihanna - Too Good
# Processing track: Julian Perretta - Miracle
# Processing track: Flo Rida - My House
# Processing track: The Strumbellas - Spirits
# Processing track: Walking On Cars - Speeding Cars
# Processing track: Adele - Hello
# Processing track: X Ambassadors - Renegades
# Processing track: Dua Lipa - Be The One
# Processing track: Twenty One Pilots - Ride
# Processing track: 257ers - Holland
# Processing track: Robin Schulz & J.U.D.G.E. - Show Me Love
# Processing track: Mark Forster - Chöre
# Processing track: SDP feat. Adel Tawil - Ich will nur dass du weißt
# Processing track: Zara Larsson & MNEK - Never Forget You
# Processing track: James Arthur - Say You Won't Let Go
# Processing track: Alvaro Soler - Sofia
# Processing track: Wincent Weiss - Musik sein
# Processing track: Robin Schulz feat. Francesco Yates - Sugar
# Processing track: Milow - Howling At The Moon
# Processing track: Sigala feat. Bryn Christopher - Sweet Lovin'
# Processing track: Robin Schulz feat. Akon - Heatwave
# Processing track: The Chainsmokers feat. Rozes - Roses
# Processing track: Miami Yacine - Kokaina
# Processing track: Zayn - Pillowtalk
# Processing track: Zara Larsson - Ain't My Fault
# Processing track: Yall feat. Gabriela Richardson - Hundred Miles
# Processing track: Ali Bumaye feat. Shindy - Sex ohne Grund
# Processing track: Meghan Trainor - No
# Processing track: Shawn Mendes - Mercy
# Processing track: Lil Kleine & Ronnie Flex - Stoff und Schnaps
# Processing track: Frenship + Emily Warren - Capsize
# No recording found for 'Frenship + Emily Warren - Capsize'
# Processing track: Ariana Grande feat. Nicki Minaj - Side To Side
# Processing track: Sido feat. Andreas Bourani - Astronaut
# Processing track: Bonez MC & RAF Camora feat. Gzuz - Mörder
# Processing track: OneRepublic - Wherever I Go
# Processing track: P!nk - Just Like Fire
# Finished processing 2016. Found MBID for 97 out of 100 tracks.
#
# Processing MBIDs for year 2017...
# Processing track: Ed Sheeran - Shape Of You
# Processing track: Luis Fonsi feat. Daddy Yankee - Despacito
# Processing track: The Chainsmokers & Coldplay - Something Just Like This
# Processing track: Imagine Dragons - Thunder
# Processing track: Burak Yeter feat. Danelle Sandoval - Tuesday
# Processing track: Axwell Λ Ingrosso - More Than You Know
# Processing track: Robin Schulz feat. James Blunt - OK
# Processing track: Bausa - Was du Liebe nennst
# Processing track: French Montana feat. Swae Lee - Unforgettable
# Processing track: Ed Sheeran - Galway Girl
# Processing track: Jason Derulo feat. Nicki Minaj & Ty Dolla $ign - Swalla
# Processing track: Ed Sheeran - Perfect
# Processing track: Kygo & Selena Gomez - It Ain't Me
# Processing track: Alice Merton - No Roots
# Processing track: J Balvin & Willy William - Mi gente
# Processing track: Jonas Blue feat. William Singe - Mama
# Processing track: Bonez MC & RAF Camora feat. Maxwell - Ohne mein Team
# Processing track: Camila Cabello feat. Young Thug - Havana
# Processing track: Shawn Mendes - There's Nothing Holdin' Me Back
# Processing track: Jax Jones feat. Raye - You Don't Know Me
# Processing track: Post Malone feat. 21 Savage - Rockstar
# Processing track: Charlie Puth - Attention
# Processing track: Ed Sheeran - Castle On The Hill
# Processing track: Zayn feat. Sia - Dusk Till Dawn
# Processing track: Kay One feat. Pietro Lombardi - Señorita
# Processing track: Ofenbach - Be Mine
# Processing track: Rita Ora - Your Song
# Processing track: DJ Khaled feat. Rihanna & Bryson Tiller - Wild Thoughts
# Processing track: Clean Bandit feat. Sean Paul & Anne-Marie - Rockabye
# Processing track: Liam Payne feat. Quavo - Strip That Down
# Processing track: Nimo - Heute mit mir
# Processing track: Zayn & Taylor Swift - I Don't Wanna Live Forever (Fifty Shades Darker)
# No recording found for 'Zayn & Taylor Swift - I Don't Wanna Live Forever (Fifty Shades Darker)'
# Processing track: Enrique Iglesias feat. Descemer Bueno, Zion & Lennox - Súbeme la radio
# Processing track: Clean Bandit feat. Zara Larsson - Symphony
# Processing track: Justin Bieber + BloodPop® - Friends
# Processing track: Gestört aber GeiL feat. Lea - Wohin willst du
# Processing track: Imagine Dragons - Believer
# Processing track: The Chainsmokers - Paris
# Processing track: P!nk - What About Us
# Processing track: DJ Khaled feat. Justin Bieber, Quavo, Chance The Rapper & Lil Wayne - I'm The One
# Processing track: Dua Lipa - New Rules
# Processing track: Lauv - I Like Me Better
# Processing track: Felix Jaehn, Hight & Alex Aiono - Hot2Touch
# Processing track: Starley - Call On Me
# Processing track: Marshmello feat. Khalid - Silence
# Processing track: David Guetta feat. Justin Bieber - 2U
# Processing track: Martin Jensen - Solo Dance
# Processing track: Mark Forster - Sowieso
# Processing track: Miami Yacine - Bon voyage
# Processing track: Cro - Unendlichkeit
# Processing track: Alle Farben & Janieck - Little Hollywood
# Processing track: Martin Garrix & Dua Lipa - Scared To Be Lonely
# Processing track: Future - Mask Off
# Processing track: Maître Gims feat. Dany Synthé - Loin
# Processing track: Adel Tawil - Ist da jemand
# Processing track: Rag'n'Bone Man - Skin
# Processing track: Zedd & Alessia Cara - Stay
# Processing track: Zuna feat. Azet & Noizy - Nummer 1
# No recording found for 'Zuna feat. Azet & Noizy - Nummer 1'
# Processing track: Calvin Harris feat. Pharrell Williams, Katy Perry & Big Sean - Feels
# Processing track: Helene Fischer - Herzbeben
# Processing track: Kaleo - Way Down We Go
# Processing track: Alan Walker - Alone
# Processing track: Mark Forster - Chöre
# Processing track: Katy Perry feat. Skip Marley - Chained To The Rhythm
# Processing track: RAF Camora - Primo
# Processing track: Welshly Arms - Legendary
# Processing track: Rin - Bros
# Processing track: Maggie Lindemann - Pretty Girl
# Processing track: Kay One - Louis Louis
# Processing track: Macklemore feat. Skylar Grey - Glorious
# Processing track: Bonez MC / RAF Camora / GZUZ / Maxwell - Kontrollieren
# No recording found for 'Bonez MC / RAF Camora / GZUZ / Maxwell - Kontrollieren'
# Processing track: Capo feat. Nimo - Lambo Diablo GT
# Processing track: RIN - Monica Bellucci
# Processing track: Ufo361 - Nice Girl 2.0
# Processing track: Harry Styles - Sign Of The Times
# Processing track: Portugal. The Man - Feel It Still
# Processing track: 187 Strassenbande feat. Bonez MC, Gzuz - Millionär
# No recording found for '187 Strassenbande feat. Bonez MC, Gzuz - Millionär'
# Processing track: Jon Bellion - All Time Low
# Processing track: Alma [FI] - Chasing Highs
# No recording found for 'Alma [FI] - Chasing Highs'
# Processing track: Robin Schulz & David Guetta feat. Cheat Codes - Shed A Light
# Processing track: Taylor Swift - Look What You Made Me Do
# Processing track: KC Rebell x Summer Cem - Murcielago
# No recording found for 'KC Rebell x Summer Cem - Murcielago'
# Processing track: Sean Paul feat. Dua Lipa - No Lie
# Processing track: Andreas Gabalier - Hulapalu
# Processing track: Rag'n'Bone Man - Human
# Processing track: Veysel - Kleiner Cabrón
# Processing track: Kurdo - Ya Salam
# Processing track: Maroon 5 feat. SZA - What Lovers Do
# Processing track: Bonez MC & RAF Camora - Palmen aus Plastik
# Processing track: Avicii feat. Sandro Cavazza - Without You
# Processing track: Alle Farben - Bad Ideas
# Processing track: Sia - Never Give Up
# Processing track: Julia Michaels - Issues
# Processing track: Sage The Gemini - Now & Later
# Processing track: Imagine Dragons - Whatever It Takes
# Processing track: Sam Smith - Too Good At Goodbyes
# Processing track: The Weeknd feat. Daft Punk - Starboy
# Processing track: Cheat Codes feat. Demi Lovato - No Promises
# Processing track: Kendrick Lamar - Humble.
# Processing track: Shakira feat. Maluma - Chantaje
# Finished processing 2017. Found MBID for 94 out of 100 tracks.
#
# Processing MBIDs for year 2018...
# Processing track: Dynoro & Gigi D'Agostino - In My Mind
# Processing track: Ed Sheeran - Perfect
# Processing track: Bausa - Was du Liebe nennst
# Processing track: Calvin Harris & Dua Lipa - One Kiss
# Processing track: Dennis Lloyd - Nevermind
# Processing track: El Profesor - Bella ciao (Hugel Remix)
# Processing track: Namika feat. Black M - Je ne parle pas français (Beatgees Remix)
# Processing track: Clean Bandit feat. Demi Lovato - Solo
# Processing track: Marshmello & Anne-Marie - Friends
# Processing track: Luis Fonsi & Demi Lovato - Échame la culpa
# Processing track: Olexesh feat. Edin - Magisch
# Processing track: Drake - God's Plan
# Processing track: Rudimental feat. Jess Glynne, Macklemore & Dan Caplen - These Days
# Processing track: Camila Cabello feat. Young Thug - Havana
# Processing track: Capital Bra feat. Ufo361 - Neymar
# Processing track: Bonez MC & RAF Camora - 500 PS
# Processing track: Eminem feat. Ed Sheeran - River
# Processing track: Summer Cem & Bausa - Casanova
# Processing track: Nico Santos - Rooftop
# Processing track: Loud Luxury feat. Brando - Body
# Processing track: Post Malone feat. 21 Savage - Rockstar
# Processing track: David Guetta & Sia - Flames
# Processing track: Tom Walker - Leave A Light On
# Processing track: Capital Bra feat. Juju - Melodien
# Processing track: Maroon 5 feat. Cardi B - Girls Like You
# Processing track: Capital Bra - One Night Stand
# Processing track: Die Fantastischen Vier feat. Clueso - Zusammen
# Processing track: Alvaro Soler - La cintura
# Processing track: Jonas Blue feat. Jack & Jack - Rise
# Processing track: Ramz - Barking
# Processing track: The Chainsmokers - Sick Boy
# Processing track: LEA - Leiser
# Processing track: Martin Garrix & David Guetta feat. Jamie Scott & Romy Dya - So Far Away
# Processing track: Ed Sheeran - Shape Of You
# Processing track: Post Malone - Better Now
# Processing track: Jason Derulo feat. French Montana - Tip Toe
# Processing track: Liam Payne & Rita Ora - For You (Fifty Shades Freed)
# Processing track: Calvin Harris & Sam Smith - Promises
# Processing track: Justin Timberlake feat. Chris Stapleton - Say Something
# Processing track: Cardi B, Bad Bunny & J Balvin - I Like It
# Processing track: G-Eazy & Halsey - Him & I
# Processing track: Lost Frequencies & Zonderling - Crazy
# Processing track: Summer Cem - Tamam Tamam
# Processing track: Nicky Jam x J Balvin - X
# Processing track: Jax Jones feat. Ina Wroldsen - Breathe
# Processing track: Ofenbach vs. Nick Waterhouse - Katchi
# Processing track: Luis Fonsi feat. Daddy Yankee - Despacito
# Processing track: Dua Lipa - IDGAF
# Processing track: Zedd / Maren Morris / Grey - The Middle
# Processing track: Rin - Dior 2001
# Processing track: Azet feat. RAF Camora - Qa bone
# No recording found for 'Azet feat. RAF Camora - Qa bone'
# Processing track: Bonez MC & RAF Camora feat. Gzuz - Kokain
# Processing track: Armin van Buuren - Blah Blah Blah
# Processing track: Panic! At The Disco - High Hopes
# Processing track: Capital Bra - 5 Songs in einer Nacht
# Processing track: Justin Bieber + BloodPop® - Friends
# Processing track: Benny Blanco, Halsey & Khalid - Eastside
# Processing track: Drake - In My Feelings
# Processing track: Kay One feat. Pietro Lombardi - Señorita
# Processing track: Robin Schulz & Marc Scibilia - Unforgettable
# Processing track: Ariana Grande - No Tears Left To Cry
# Processing track: Sean Paul + David Guetta feat. Becky G - Mad Love
# No recording found for 'Sean Paul + David Guetta feat. Becky G - Mad Love'
# Processing track: Eli [DE] - Change Your Mind
# No recording found for 'Eli [DE] - Change Your Mind'
# Processing track: NF - Let You Down
# Processing track: Kygo feat. Miguel - Remind Me To Forget
# No recording found for 'Kygo feat. Miguel - Remind Me To Forget'
# Processing track: George Ezra - Shotgun
# Processing track: Rea Garvey feat. Kool Savas - Is It Love?
# Processing track: Rita Ora - Anywhere
# Processing track: Dardan - Facetime
# Processing track: Eno - Mercedes
# Processing track: Selena Gomez x Marshmello - Wolves
# No recording found for 'Selena Gomez x Marshmello - Wolves'
# Processing track: XXXTentacion - Sad!
# Processing track: Leon Machère - Copacabana
# Processing track: Post Malone feat. Ty Dolla $ign - Psycho
# Processing track: Marshmello feat. Khalid - Silence
# Processing track: Portugal. The Man - Feel It Still
# Processing track: Pietro Lombardi - Phänomenal
# Processing track: Marshmello & Bastille - Happier
# Processing track: Bushido feat. Samra & Capital Bra - Für euch alle
# No recording found for 'Bushido feat. Samra & Capital Bra - Für euch alle'
# Processing track: Loredana x Mozzik - Bonnie & Clyde
# No recording found for 'Loredana x Mozzik - Bonnie & Clyde'
# Processing track: Bonez MC & RAF Camora - Risiko
# Processing track: Axwell Λ Ingrosso - More Than You Know
# Processing track: George Ezra - Paradise
# Processing track: Dean Lewis - Be Alright
# Processing track: James Hype feat. Kelli-Leigh - More Than Friends
# Processing track: Imagine Dragons - Whatever It Takes
# Processing track: Kygo & Imagine Dragons - Born To Be Yours
# Processing track: Capital Bra - Berlin lebt
# Processing track: Shawn Mendes - In My Blood
# Processing track: J Balvin & Willy William - Mi gente
# Processing track: Zayn feat. Sia - Dusk Till Dawn
# Processing track: Alle Farben, Kelvin Jones & Younotus - Only Thing We Know
# Processing track: Felix Jaehn feat. R. City & Bori - Jennie
# Processing track: Anne-Marie - 2002
# Processing track: Wincent Weiss - An Wunder
# Processing track: Robin Schulz & Piso 21 - Oh Child
# Processing track: Lea x Cyril - Immer wenn wir uns sehn
# No recording found for 'Lea x Cyril - Immer wenn wir uns sehn'
# Processing track: RAF Camora - Primo
# Processing track: KitschKrieg feat. Trettmann, Gringo, Ufo361 & Gzuz - Standard
# Processing track: Dua Lipa - New Rules
# Finished processing 2018. Found MBID for 92 out of 100 tracks.
#
# Processing MBIDs for year 2019...
# Processing track: Lil Nas X - Old Town Road
# Processing track: Tones And I - Dance Monkey
# Processing track: Apache 207 - Roller
# Processing track: Juju feat. Henning May - Vermissen
# Processing track: Ava Max - Sweet But Psycho
# Processing track: Billie Eilish - Bad Guy
# Processing track: Shawn Mendes & Camila Cabello - Señorita
# Processing track: Ed Sheeran & Justin Bieber - I Don't Care
# Processing track: Capital Bra x Samra - Tilidin
# No recording found for 'Capital Bra x Samra - Tilidin'
# Processing track: Samra & Capital Bra - Wieder Lila
# No recording found for 'Samra & Capital Bra - Wieder Lila'
# Processing track: Daddy Yankee feat. Snow - Con calma
# No recording found for 'Daddy Yankee feat. Snow - Con calma'
# Processing track: Lewis Capaldi - Someone You Loved
# Processing track: Meduza feat. Goodboys - Piece Of Your Heart
# Processing track: Capital Bra x Samra & Lea - 110
# No recording found for 'Capital Bra x Samra & Lea - 110'
# Processing track: Sarah Connor - Vincent
# Processing track: Lady Gaga & Bradley Cooper - Shallow
# Processing track: Bonez MC & RAF Camora - 500 PS
# Processing track: Mabel [UK] - Don't Call Me Up
# No recording found for 'Mabel [UK] - Don't Call Me Up'
# Processing track: Dynoro & Gigi D'Agostino - In My Mind
# Processing track: Rammstein - Deutschland
# Processing track: Capital Bra - Cherry Lady
# Processing track: Apache 207 - 200 km/h
# Processing track: Capital Bra - Benzema
# Processing track: Capital Bra - Prinzessa
# Processing track: Ed Sheeran feat. Khalid - Beautiful People
# Processing track: Bausa - Mary
# Processing track: Robin Schulz feat. Erika Sirola - Speechless
# Processing track: Panic! At The Disco - High Hopes
# Processing track: Mero - Wolke 10
# Processing track: DJ Snake & J Balvin feat. Tyga - Loco contigo
# No recording found for 'DJ Snake & J Balvin feat. Tyga - Loco contigo'
# Processing track: Sido - Tausend Tattoos
# Processing track: Imagine Dragons - Bad Liar
# Processing track: Calvin Harris & Rag'n'Bone Man - Giant
# Processing track: Loredana feat. Mozzik - Eiskalt
# Processing track: Mero - Baller los
# Processing track: Avicii feat. Aloe Blacc - SOS
# Processing track: Shirin David - Gib ihm
# Processing track: C Arma - Yapma
# Processing track: Post Malone - Wow.
# Processing track: Loredana - Jetzt rufst du an
# Processing track: Ariana Grande - 7 Rings
# Processing track: KC Rebell feat. Summer Cem & Capital Bra - DNA
# No recording found for 'KC Rebell feat. Summer Cem & Capital Bra - DNA'
# Processing track: Apache 207 - Wieso tust Du dir das an?
# Processing track: Summer Cem feat. Capital Bra - Diamonds
# Processing track: Dardan - Coco Mama
# Processing track: Vize feat. Laniia - Stars
# Processing track: Mero - Hobby Hobby
# Processing track: Younotus & Janieck & Senex - Narcotic
# Processing track: Halsey - Without Me
# Processing track: Capital Bra feat. Summer Cem & KC Rebell - Rolex
# Processing track: Jonas Brothers - Sucker
# Processing track: Sido feat. Apache 207 - 2002
# Processing track: Shindy - Nautilus
# Processing track: Shindy - Affalterbach
# Processing track: Alec Benjamin - Let Me Down Slowly
# Processing track: Capital Bra x Samra - Wir ticken
# No recording found for 'Capital Bra x Samra - Wir ticken'
# Processing track: KitschKrieg feat. Trettmann, Gringo, Ufo361 & Gzuz - Standard
# Processing track: Kygo x Whitney Houston - Higher Love
# Processing track: OneRepublic - Rescue Me
# Processing track: Loredana feat. Mero - Kein Plan
# Processing track: Alle Farben & Ilira - Fading
# Processing track: Shindy - DODI
# Processing track: Mark Ronson feat. Miley Cyrus - Nothing Breaks Like A Heart
# Processing track: Tim Bendzko - Hoch
# Processing track: Lum!x & Gabry Ponte - Monster
# Processing track: Dean Lewis - Be Alright
# Processing track: R3hab x A Touch Of Class - All Around The World (La La La)
# Processing track: The Prince Karma - Later Bitches
# Processing track: Loud Luxury feat. Brando - Body
# Processing track: Shirin David feat. Maître Gims - On Off
# Processing track: Eno feat. Mero - Ferrari
# Processing track: Luciano - La haine
# Processing track: Samra x Capital Bra - Huracan
# No recording found for 'Samra x Capital Bra - Huracan'
# Processing track: Regard - Ride It
# Processing track: Eno - Blackberry Sky
# Processing track: Robin Schulz feat. Harlœ - All This Love
# Processing track: The Cratez & Bonez MC - Honda Civic
# No recording found for 'The Cratez & Bonez MC - Honda Civic'
# Processing track: Gaullin - Moonlight
# Processing track: Lena x Nico Santos - Better
# No recording found for 'Lena x Nico Santos - Better'
# Processing track: Marshmello & Bastille - Happier
# Processing track: Samra x Capital Bra - Zombie
# No recording found for 'Samra x Capital Bra - Zombie'
# Processing track: Kerstin Ott & Helene Fischer - Regenbogenfarben
# Processing track: Dominic Fike - 3 Nights
# Processing track: DJ Snake feat. Selena Gomez, Ozuna & Cardi B - Taki Taki
# Processing track: Fero47 - Jaja
# Processing track: Post Malone - Circles
# Processing track: Samra - Harami
# Processing track: RIN & Bausa - Keine Liebe
# Processing track: Loredana - Genick
# Processing track: Post Malone feat. Young Thug - Goodbyes
# Processing track: SDP feat. Capital Bra - Viva la Dealer
# Processing track: Summer Cem feat. Luciano - Summer Cem
# Processing track: Apache 207 - Kein Problem
# Processing track: KC Rebell - Alleen
# Processing track: Martin Garrix feat. Macklemore & Patrick Stump of Fall Out Boy - Summer Days
# Processing track: Ava Max - So Am I
# Processing track: Kontra K feat. Veysel - Blei
# Processing track: Capital Bra x Samra - Nummer 1
# No recording found for 'Capital Bra x Samra - Nummer 1'
# Processing track: Ufo361 feat. Data Luv - Shot
# Processing track: The Chainsmokers & Illenium feat. Lennon Stella - Takeaway
# No recording found for 'The Chainsmokers & Illenium feat. Lennon Stella - Takeaway'
# Finished processing 2019. Found MBID for 86 out of 100 tracks.
#
# Processing MBIDs for year 2020...
# Processing track: The Weeknd - Blinding Lights
# Processing track: Tones And I - Dance Monkey
# Processing track: Apache 207 - Roller
# Processing track: SAINt JHN - Roses (Imanbek Remix)
# Processing track: Topic feat. A7S - Breaking Me
# Processing track: Ufo361 - Emotions
# Processing track: Jawsh 685 & Jason Derulo - Savage Love (Laxed - Siren Beat)
# Processing track: DaBaby feat. Roddy Ricch - Rockstar
# Processing track: Regard - Ride It
# Processing track: Apache 207 - Fame
# Processing track: Nea - Some Say
# Processing track: Pashanim - Airwaves
# Processing track: Apache 207 - Bläulich
# Processing track: Robin Schulz feat. Alida - In Your Eyes
# Processing track: Mark Forster - Übermorgen
# Processing track: Vize & Tom Gregory - Never Let Me Down
# Processing track: Ava Max - Kings & Queens
# Processing track: 24kGoldn feat. Iann Dior - Mood
# Processing track: Dua Lipa - Don't Start Now
# Processing track: Apache 207 - 200 km/h
# Processing track: AK Ausserkontrolle x Bonez MC - In meinem Benz
# No recording found for 'AK Ausserkontrolle x Bonez MC - In meinem Benz'
# Processing track: Surf Mesa feat. Emilee - ILY (I Love You Baby)
# Processing track: Lum!x & Gabry Ponte - Monster
# Processing track: Juju x Loredana - Kein Wort
# No recording found for 'Juju x Loredana - Kein Wort'
# Processing track: KitschKrieg feat. Jamule - Unterwegs
# Processing track: Joel Corry feat. MNEK - Head & Heart
# Processing track: Capital Bra x Samra & Lea - 110
# No recording found for 'Capital Bra x Samra & Lea - 110'
# Processing track: Twocolors - Lovefool
# Processing track: Robin Schulz & Wes - Alane
# Processing track: Joker Bra & Vize - Baby
# Processing track: Apache 207 - Boot
# Processing track: Felix Jaehn & Vize feat. Miss Li - Close Your Eyes
# Processing track: Ava Max - Salt
# Processing track: Internet Money & Gunna feat. Don Toliver & Nav - Lemonade
# No recording found for 'Internet Money & Gunna feat. Don Toliver & Nav - Lemonade'
# Processing track: Roddy Ricch - The Box
# Processing track: Lewis Capaldi - Someone You Loved
# Processing track: Drake - Toosie Slide
# Processing track: Bausa x Joshi Mizu x Maxwell - Skifahren
# No recording found for 'Bausa x Joshi Mizu x Maxwell - Skifahren'
# Processing track: Bonez MC - Roadrunner
# Processing track: Billie Eilish - Bad Guy
# Processing track: Trevor Daniel - Falling
# Processing track: Kayef - Ich würd' lügen
# Processing track: Harry Styles - Watermelon Sugar
# Processing track: LA Vision & Gigi D'Agostino - Hollywood
# Processing track: Ofenbach & Quarterhead feat. Norma Jean Martine - Head Shoulders Knees & Toes
# Processing track: Sido feat. Apache 207 - 2002
# Processing track: RIN - Alien
# Processing track: Dua Lipa - Physical
# Processing track: Master KG feat. Burna Boy & Nomcebo Zikode - Jerusalema (Remix)
# Processing track: Fourty - Weisser Rauch
# Processing track: Vize x Joker Bra x Leony - Paradise
# No recording found for 'Vize x Joker Bra x Leony - Paradise'
# Processing track: Nimo & Hava - Kein Schlaf
# Processing track: Apache 207 - Wieso tust Du dir das an?
# Processing track: Juju feat. Henning May - Vermissen
# Processing track: Benee feat. Gus Dapperton - Supalonely
# Processing track: Mark Forster - 194 Länder
# Processing track: Capital Bra x Loredana - Nicht verdient
# No recording found for 'Capital Bra x Loredana - Nicht verdient'
# Processing track: Billie Eilish - Everything I Wanted
# Processing track: Lea & Capital Bra - 7 Stunden
# Processing track: Capital Bra x Clueso x KC Rebell - Andere Welt
# No recording found for 'Capital Bra x Clueso x KC Rebell - Andere Welt'
# Processing track: Bonez MC - Big Body Benz
# Processing track: Miksu / Macloud / Summer Cem / Luciano / Jamule - XXL
# No recording found for 'Miksu / Macloud / Summer Cem / Luciano / Jamule - XXL'
# Processing track: LEA - Treppenhaus
# Processing track: Capital Bra x Cro - Frühstück in Paris
# No recording found for 'Capital Bra x Cro - Frühstück in Paris'
# Processing track: Jason Derulo - Take You Dancing
# Processing track: Zoe Wees - Control
# Processing track: Samra - Colt
# Processing track: Powfu feat. Beabadoobee - Death Bed
# Processing track: Maroon 5 - Memories
# Processing track: Bausa x Juju - 2012
# No recording found for 'Bausa x Juju - 2012'
# Processing track: Apache 207 - Unterwegs
# Processing track: Riton x Oliver Heldens feat. Vula - Turn Me On
# Processing track: RIN & Bausa - Keine Liebe
# Processing track: Tyga - Ayy Macarena
# Processing track: Bonez MC - Angeklagt
# Processing track: Black Eyed Peas x J Balvin - Ritmo (Bad Boys For Life)
# Processing track: Samra x Elif - Zu Ende
# Processing track: Purple Disco Machine & Sophie And The Giants - Hypnotized
# Processing track: Future feat. Drake - Life Is Good
# Processing track: KC Rebell x Summer Cem - Fly
# No recording found for 'KC Rebell x Summer Cem - Fly'
# Processing track: Kool Savas x Alies - AMG
# No recording found for 'Kool Savas x Alies - AMG'
# Processing track: Meduza x Becky Hill x Goodboys - Lose Control
# Processing track: Dardan & Monet192 - H <3 T E L
# Processing track: Céline [DE] - Tränen aus Kajal
# No recording found for 'Céline [DE] - Tränen aus Kajal'
# Processing track: Samra - Weiss
# Processing track: Sam Feldt feat. Rani - Post Malone
# Processing track: Black Eyed Peas / Ozuna + J. Rey Soul - Mamacita
# No recording found for 'Black Eyed Peas / Ozuna + J. Rey Soul - Mamacita'
# Processing track: Lewis Capaldi - Before You Go
# Processing track: Arizona Zervas - Roxanne
# Processing track: Jerome [DE] - Light
# No recording found for 'Jerome [DE] - Light'
# Processing track: Nico Santos & Topic - Like I Love You
# Processing track: Apache 207 - Matrix
# Processing track: Tujamo - Vize - Majan - Lonely
# No recording found for 'Tujamo - Vize - Majan - Lonely'
# Processing track: Kontra K feat. Samra - Tiefschwarz
# Processing track: Bonez MC - Fuckst mich nur ab
# Processing track: Cardi B feat. Megan Thee Stallion - WAP
# Processing track: Post Malone - Circles
# Processing track: Apache 207 - Doch in der Nacht
# Processing track: Lady Gaga & Ariana Grande - Rain On Me
# Processing track: Miley Cyrus - Midnight Sky
# Finished processing 2020. Found MBID for 83 out of 100 tracks.
#
# Processing MBIDs for year 2021...
# Processing track: Nathan Evans - Wellerman
# Processing track: Ed Sheeran - Bad Habits
# Processing track: Tiësto - The Business
# Processing track: Riton x Nightcrawlers feat. Mufasa & Hypeman - Friday (Dopamine Re-Edit)
# Processing track: The Weeknd - Save Your Tears
# Processing track: The Kid Laroi / Justin Bieber - Stay
# No recording found for 'The Kid Laroi / Justin Bieber - Stay'
# Processing track: Shouse - Love Tonight
# Processing track: atb x Topic x A7S - Your Love (9PM)
# Processing track: The Weeknd - Blinding Lights
# Processing track: Olivia Rodrigo - Good 4 U
# Processing track: Bausa feat. Apache 207 - Madonna
# No recording found for 'Bausa feat. Apache 207 - Madonna'
# Processing track: Joel Corry feat. MNEK - Head & Heart
# Processing track: Lil Nas X - Montero (Call Me By Your Name)
# Processing track: Måneskin - Beggin'
# Processing track: Masked Wolf - Astronaut In The Ocean
# Processing track: Pashanim - Sommergewitter
# Processing track: Montez - Auf & ab
# Processing track: Kasimir1441 x Badmómzjay - Ohne Dich
# No recording found for 'Kasimir1441 x Badmómzjay - Ohne Dich'
# Processing track: Glass Animals - Heat Waves
# Processing track: 24kGoldn feat. Iann Dior - Mood
# Processing track: P!nk + Willow Sage Hart - Cover Me In Sunshine
# Processing track: Zoe Wees - Girls Like Us
# Processing track: The Kid Laroi - Without You
# Processing track: Jason Derulo x Nuka - Love Not War (The Tampa Beat)
# Processing track: Måneskin - I Wanna Be Your Slave
# Processing track: Olivia Rodrigo - Drivers License
# Processing track: RAF Camora feat. Bonez MC - Blaues Licht
# No recording found for 'RAF Camora feat. Bonez MC - Blaues Licht'
# Processing track: Ofenbach & Quarterhead feat. Norma Jean Martine - Head Shoulders Knees & Toes
# Processing track: Robin Schulz feat. Kiddo - All We Got
# Processing track: Apache 207 - Roller
# Processing track: Ofenbach feat. Lagique - Wasted Love
# Processing track: Justin Wellington and Small Jam - Iko Iko
# Processing track: Ed Sheeran - Shivers
# Processing track: Master KG feat. Burna Boy & Nomcebo Zikode - Jerusalema (Remix)
# Processing track: Meduza feat. Dermot Kennedy - Paradise
# Processing track: Jamule - Liege wieder wach
# Processing track: Justin Bieber feat. Daniel Caesar & Giveon - Peaches
# Processing track: Lost Frequencies / Calum Scott - Where Are You Now
# No recording found for 'Lost Frequencies / Calum Scott - Where Are You Now'
# Processing track: Shirin David - Ich darf das
# Processing track: Mark Forster x Lea - Drei Uhr nachts
# No recording found for 'Mark Forster x Lea - Drei Uhr nachts'
# Processing track: Miksu / Macloud / Jamule / Nimo - Frag mich nicht
# No recording found for 'Miksu / Macloud / Jamule / Nimo - Frag mich nicht'
# Processing track: Dua Lipa - Levitating
# Processing track: Lil Nas X & Jack Harlow - Industry Baby
# Processing track: Tones And I - Dance Monkey
# Processing track: Tinlicker & Helsloot - Because You Move Me
# Processing track: Leony - Faded Love
# Processing track: Pajel - 10von10
# Processing track: Purple Disco Machine & Sophie And The Giants - Hypnotized
# Processing track: Elton John & Dua Lipa - Cold Heart
# Processing track: Vize x Tokio Hotel - White Lies
# Processing track: Ed Sheeran - Afterglow
# Processing track: Mariah Carey - All I Want For Christmas Is You
# Processing track: Samra x Topic42 - Lost
# Processing track: OneRepublic - Run
# Processing track: Tate McRae - You Broke Me First
# Processing track: Shirin David - Lieben wir
# Processing track: Wes Nelson & Yxng Bane - Nice To Meet Ya
# No recording found for 'Wes Nelson & Yxng Bane - Nice To Meet Ya'
# Processing track: Wincent Weiss - Wer wenn nicht wir
# Processing track: CKay feat. ElGrande Toto - Love Nwantiti (North African Remix)
# Processing track: SAINt JHN - Roses (Imanbek Remix)
# Processing track: Wham! - Last Christmas
# Processing track: Jawsh 685 & Jason Derulo - Savage Love (Laxed - Siren Beat)
# Processing track: 187 Strassenbande / Bonez, Frauenarzt - Extasy
# No recording found for '187 Strassenbande / Bonez, Frauenarzt - Extasy'
# Processing track: 01099 - Gustav, Zachi - Durstlöscher
# No recording found for '01099 - Gustav, Zachi - Durstlöscher'
# Processing track: HVME - Goosebumps
# Processing track: Topic feat. A7S - Breaking Me
# Processing track: Adele - Easy On Me
# Processing track: Tom Odell - Another Love
# Processing track: Twocolors - Lovefool
# Processing track: Milky Chance - Colorado
# Processing track: Farruko - Pepas
# Processing track: Apache 207 - Angst
# Processing track: ART [DE] - Belgisches Viertel
# No recording found for 'ART [DE] - Belgisches Viertel'
# Processing track: Joel Corry / Raye / David Guetta - Bed
# No recording found for 'Joel Corry / Raye / David Guetta - Bed'
# Processing track: Ava Max - My Head & My Heart
# Processing track: Alvaro Soler - Magia
# Processing track: Travis Scott feat. Kendrick Lamar - Goosebumps
# Processing track: Coldplay - Higher Power
# Processing track: Robin Schulz & Felix Jaehn feat. Alida - One More Time
# Processing track: Santos x Sido x Samra - Leere Hände
# No recording found for 'Santos x Sido x Samra - Leere Hände'
# Processing track: RAF Camora x Juju - Wenn du mich siehst
# No recording found for 'RAF Camora x Juju - Wenn du mich siehst'
# Processing track: Mark Forster - Übermorgen
# Processing track: 01099 - Gustav - Frisch
# No recording found for '01099 - Gustav - Frisch'
# Processing track: Luciano - Schmetterling
# Processing track: Joel Corry & Jax Jones feat. Charli XCX & Saweetie - Out Out
# Processing track: Super-Hi x Neeka - Following The Sun
# No recording found for 'Super-Hi x Neeka - Following The Sun'
# Processing track: RAF Camora feat. Luciano - 2CB
# No recording found for 'RAF Camora feat. Luciano - 2CB'
# Processing track: CJ - Whoopty
# Processing track: Luna [DE] - Verlierer
# No recording found for 'Luna [DE] - Verlierer'
# Processing track: Miley Cyrus feat. Dua Lipa - Prisoner
# Processing track: Chris Rea - Driving Home For Christmas
# Processing track: Doja Cat feat. SZA - Kiss Me More
# Processing track: Cro feat. Capital Bra - Blessed
# No recording found for 'Cro feat. Capital Bra - Blessed'
# Processing track: Vize x Joker Bra x Leony - Paradise
# No recording found for 'Vize x Joker Bra x Leony - Paradise'
# Processing track: Doja Cat - Woman
# Processing track: Helene Fischer feat. Luis Fonsi - Vamos a marte
# Processing track: HBz - King Kong
# Processing track: Internet Money & Gunna feat. Don Toliver & Nav - Lemonade
# No recording found for 'Internet Money & Gunna feat. Don Toliver & Nav - Lemonade'
# Processing track: Melanie Thornton - Wonderful Dream (Holidays Are Coming)
# Processing track: Shakin' Stevens - Merry Christmas Everyone
# Finished processing 2021. Found MBID for 79 out of 100 tracks.
#
# Processing MBIDs for year 2022...
# Processing track: DJ Robin & Schürze - Layla
# Processing track: Glass Animals - Heat Waves
# Processing track: Luciano - Beautiful Girl
# Processing track: Gayle - abcdefu
# Processing track: Ed Sheeran - Shivers
# Processing track: Harry Styles - As It Was
# Processing track: Lost Frequencies / Calum Scott - Where Are You Now
# No recording found for 'Lost Frequencies / Calum Scott - Where Are You Now'
# Processing track: Miksu / MacLoud & T-Low - Sehnsucht
# Processing track: Elton John & Dua Lipa - Cold Heart
# Processing track: Nina Chuba - Wildberry Lillet
# Processing track: Farruko - Pepas
# Processing track: Miksu / MacLoud / Makko - Nachts wach
# No recording found for 'Miksu / MacLoud / Makko - Nachts wach'
# Processing track: Tom Odell - Another Love
# Processing track: Ed Sheeran - Bad Habits
# Processing track: Ion Miles / SiraOne / BHZ - Powerade
# No recording found for 'Ion Miles / SiraOne / BHZ - Powerade'
# Processing track: The Kid Laroi / Justin Bieber - Stay
# No recording found for 'The Kid Laroi / Justin Bieber - Stay'
# Processing track: Tiësto & Ava Max - The Motto
# Processing track: Imagine Dragons x JID - Enemy
# Processing track: Montez - Auf & ab
# Processing track: Acraze feat. Cherish - Do It To It
# Processing track: Leony - Remedy
# Processing track: Domiziana - Ohne Benzin
# Processing track: James Hype & Miggy Dela Rosa - Ferrari
# Processing track: Imanbek & BYOR - Belly Dancer
# Processing track: Jason Derulo - Acapulco
# Processing track: Shouse - Love Tonight
# Processing track: Jaymes Young - Infinity
# Processing track: Liaze - Paradise
# Processing track: T-Low & Miksu / Macloud - We Made It
# No recording found for 'T-Low & Miksu / Macloud - We Made It'
# Processing track: David Guetta & Bebe Rexha - I'm Good (Blue)
# Processing track: Öwnboss & Sevek - Move Your Body
# Processing track: Nathan Evans - Wellerman
# Processing track: Sido - Mit Dir
# Processing track: Civo - Weg von mir
# Processing track: Kate Bush - Running Up That Hill
# Processing track: Kummer feat. Fred Rabe - Der letzte Song (Alles wird gut)
# Processing track: Luciano x Aitch x Bia - Bamba
# No recording found for 'Luciano x Aitch x Bia - Bamba'
# Processing track: Camila Cabello feat. Ed Sheeran - Bam Bam
# Processing track: Julian Sommer - Dicht im Flieger
# Processing track: Rosa Linn - Snap
# Processing track: Kamrad - I Believe
# Processing track: Kontra K feat. Sido & Leony - Follow
# Processing track: Sam Smith & Kim Petras - Unholy
# Processing track: Pajel - 10von10
# Processing track: Purple Disco Machine + Sophie And The Giants - In The Dark
# No recording found for 'Purple Disco Machine + Sophie And The Giants - In The Dark'
# Processing track: Luude feat. Colin Hay - Down Under
# Processing track: Lil Nas X - Thats What I Want
# Processing track: Southstar - Miss You
# Processing track: Jack Harlow - First Class
# Processing track: Elley Duhé - Middle Of The Night
# Processing track: The Weeknd - Save Your Tears
# Processing track: Alvaro Soler / Ray Dalton - Manila
# No recording found for 'Alvaro Soler / Ray Dalton - Manila'
# Processing track: Peter Fox feat. Inéz - Zukunft Pink
# Processing track: Pashanim - Sommergewitter
# Processing track: RAF Camora feat. Bonez MC - Blaues Licht
# No recording found for 'RAF Camora feat. Bonez MC - Blaues Licht'
# Processing track: 1986zig - Kopf aus
# Processing track: Glockenbach x ClockClock - Brooklyn
# No recording found for 'Glockenbach x ClockClock - Brooklyn'
# Processing track: OneRepublic - I Ain't Worried
# Processing track: SDP feat. Clueso - Die schönsten Tage
# Processing track: The Weeknd - Blinding Lights
# Processing track: Die Zipfelbuben feat. DJ Cashi - Olivia
# Processing track: Lil Nas X & Jack Harlow - Industry Baby
# Processing track: Chris Brown - Under The Influence
# Processing track: Apache 207 - Roller
# Processing track: Olivia Rodrigo - Good 4 U
# Processing track: Endzone / TM - 61 Grad
# No recording found for 'Endzone / TM - 61 Grad'
# Processing track: Jax Jones feat. MNEK - Where Did You Go?
# Processing track: Robin Schulz & Dennis Lloyd - Young Right Now
# Processing track: Emilio - Ausmacht
# Processing track: David Guetta, Becky Hill & Ella Henderson - Crazy What Love Can Do
# Processing track: Mariah Carey - All I Want For Christmas Is You
# Processing track: Adele - Easy On Me
# Processing track: ClockClock - Sorry
# Processing track: Benzz - Je m'appelle
# Processing track: Wham! - Last Christmas
# Processing track: Tinlicker & Helsloot - Because You Move Me
# Processing track: Topic x A7S - Kernkraft 400 (A Better Day)
# No recording found for 'Topic x A7S - Kernkraft 400 (A Better Day)'
# Processing track: Panic! At The Disco - House Of Memories
# Processing track: Riton x Nightcrawlers feat. Mufasa & Hypeman - Friday (Dopamine Re-Edit)
# Processing track: Gzuz - Späti
# Processing track: Nicky Youre & Dazy - Sunroof
# Processing track: Macklemore & Ryan Lewis feat. Ray Dalton - Can't Hold Us
# Processing track: Shawn Mendes - When You're Gone
# Processing track: Rammstein - Zick zack
# Processing track: Rammstein - Zeit
# Processing track: Coldplay x BTS - My Universe
# Processing track: Tate McRae - She's All I Wanna Be
# Processing track: Central Cee - Doja
# Processing track: CKay feat. ElGrande Toto - Love Nwantiti (North African Remix)
# Processing track: Rema - Calm Down
# Processing track: Pascal Letoublon feat. Leony - Friendships (Lost My Love)
# Processing track: Pashanim - Paris Freestyle
# Processing track: Felix Jaehn & The Stickmen Project feat. Calum Scott - Rain In Ibiza
# Processing track: Malik Harris - Rockstars
# Processing track: Swedish House Mafia & The Weeknd - Moth To A Flame
# Processing track: Bonez MC & RAF Camora - Letztes Mal
# Processing track: Bonez MC / RAF Camora - Sommer
# No recording found for 'Bonez MC / RAF Camora - Sommer'
# Processing track: Chris Rea - Driving Home For Christmas
# Processing track: Alle Farben feat. Kiddo - Alright
# Processing track: Taylor Swift - Anti-Hero
# Finished processing 2022. Found MBID for 87 out of 100 tracks.

# %%
# Save  MBID DataFrames to a CSV file
for year, df in mbid_yearly.items():
    filename = f"tracks_mbids_{year}.csv"
    df.to_csv(filename, index=False, encoding='utf-8')
    print(f"CSV file for {year} saved as '{filename}'")


#mbid_yearly[2015].to_csv('tracks_mbids_2015.csv', index=False, encoding='utf-8')
#print("CSV file for 2015 has been saved as 'tracks_mbids_2015.csv'")
# Out:
# CSV file for 2015 saved as 'tracks_mbids_2015.csv'
# CSV file for 2016 saved as 'tracks_mbids_2016.csv'
# CSV file for 2017 saved as 'tracks_mbids_2017.csv'
# CSV file for 2018 saved as 'tracks_mbids_2018.csv'
# CSV file for 2019 saved as 'tracks_mbids_2019.csv'
# CSV file for 2020 saved as 'tracks_mbids_2020.csv'
# CSV file for 2021 saved as 'tracks_mbids_2021.csv'
# CSV file for 2022 saved as 'tracks_mbids_2022.csv'

# %%
mbid_yearly[2015]
# Out:
#    Position                                   Artist  \
# 0         1                                      Omi
# 1         2                         Lost Frequencies
# 2         3       Felix Jaehn feat. Jasmine Thompson
# 3         4                           Ellie Goulding
# 4         5          Major Lazer & DJ Snake feat. MØ
# ..      ...                                      ...
# 95       96                          Pitbull & Ne-Yo
# 96       97                 K.I.Z. feat. Henning May
# 97       98                            Justin Bieber
# 98       99                  Mark Forster feat. Sido
# 99      100  Lilly Wood & The Prick and Robin Schulz
#
#                                Title                                  MBID
# 0    Cheerleader (Felix Jaehn Remix)  38629b7b-d103-4659-a8ad-5b5634a59dbb
# 1                    Are You With Me  ee3ce507-2d82-4493-bebd-b55e9e8cb863
# 2     Ain't Nobody (Loves Me Better)  d61e5ae9-f9c0-4a5b-9f98-b0db7f98e439
# 3                Love Me Like You Do  8f8a3f12-bf98-4599-8d3e-3e41b3a2a7e2
# 4                            Lean On  bddbcf90-0aed-47bc-bf32-6ab21d7881de
# ..                               ...                                   ...
# 95                 Time Of Our Lives  e0dfb145-a0af-4df4-9f5c-89ad509106f3
# 96         Hurra die Welt geht unter  b840777b-b91d-47d0-af7c-f5372cdd79eb
# 97                     Love Yourself  a9adb57f-6812-4bd8-98e6-deadb328ebd3
# 98                         Au revoir  e8310a5d-203d-4d64-a9e0-1bb5f436635b
# 99  Prayer In C (Robin Schulz Remix)  f6f8f236-2898-4fc9-af3a-28c0b682b944
#
# [100 rows x 4 columns]

# %%
def search_high_audio_features(mbid):
     """
     Retrieve high-level acoustic features from AcousticBrainz using the provided MBID.
     Returns a dictionary with audio features if successful, or None otherwise.
     """
     url = f"https://acousticbrainz.org/api/v1/{mbid}/high-level"
     response = requests.get(url)
     if response.status_code != 200:
         print(f"AcousticBrainz error for MBID high-level {mbid}: HTTP {response.status_code}")
         return None
     return response.json()

def search_audio_features(mbid):
     """
     Retrieve low-level acoustic features from AcousticBrainz using the provided MBID.
     Returns a dictionary with audio features if successful, or None otherwise.
     """
     url = f"https://acousticbrainz.org/api/v1/{mbid}/low-level"
     response = requests.get(url)
     if response.status_code != 200:
         print(f"AcousticBrainz error for MBID low-level {mbid}: HTTP {response.status_code}")
         return None
     return response.json()

df_2015 = mbid_yearly[2015].copy()

# Prepare a list to collect the audio features for each track.
low_audio_features_list = []
high_audio_features_list = []

print("Iterating over all tracks in the 2015 dataset to retrieve audio features...")
for idx, row in df_2015.iterrows():
    mbid = row.get("MBID")
    if mbid:
        features_low = search_audio_features(mbid)
        features_high = search_high_audio_features(mbid)
        if (features_low is not None):
            print(f"Got low audio features for track '{row['Title']}' by {row['Artist']}.")
        else:
            print(f"Low audio features not found for track '{row['Title']}' by {row['Artist']}.")
        if (features_high is not None):
            print(f"Got high audio features for track '{row['Title']}' by {row['Artist']}.")
        else:
            print(f"High audio features not found for track '{row['Title']}' by {row['Artist']}.")
    else:
        print(f"No MBID for track '{row['Title']}' by {row['Artist']}")
        features = None
    low_audio_features_list.append(features_low)
    high_audio_features_list.append(features_high)
    # Delay to avoid hitting API rate limits
    time.sleep(1)
# Out:
# Iterating over all tracks in the 2015 dataset to retrieve audio features...
# AcousticBrainz error for MBID low-level d15b0f43-ac17-4c01-95f1-687c5456093a: HTTP 404
# AcousticBrainz error for MBID high-level d15b0f43-ac17-4c01-95f1-687c5456093a: HTTP 404
# Low audio features not found for track 'Cheerleader (Felix Jaehn Remix)' by Omi.
# High audio features not found for track 'Cheerleader (Felix Jaehn Remix)' by Omi.
# Got low audio features for track 'Are You With Me' by Lost Frequencies.
# Got high audio features for track 'Are You With Me' by Lost Frequencies.
# AcousticBrainz error for MBID low-level bad77138-96a6-4b39-be33-2e5b0dd2a838: HTTP 404
# AcousticBrainz error for MBID high-level bad77138-96a6-4b39-be33-2e5b0dd2a838: HTTP 404
# Low audio features not found for track 'Ain't Nobody (Loves Me Better)' by Felix Jaehn feat. Jasmine Thompson.
# High audio features not found for track 'Ain't Nobody (Loves Me Better)' by Felix Jaehn feat. Jasmine Thompson.
# AcousticBrainz error for MBID low-level 161efdaf-9742-4e82-97df-7f0c4e59cbc3: HTTP 404
# AcousticBrainz error for MBID high-level 161efdaf-9742-4e82-97df-7f0c4e59cbc3: HTTP 404
# Low audio features not found for track 'Love Me Like You Do' by Ellie Goulding.
# High audio features not found for track 'Love Me Like You Do' by Ellie Goulding.
# AcousticBrainz error for MBID low-level 1e3a21a1-86a8-4cef-82be-b989c20ab113: HTTP 404
# AcousticBrainz error for MBID high-level 1e3a21a1-86a8-4cef-82be-b989c20ab113: HTTP 404
# Low audio features not found for track 'Lean On' by Major Lazer & DJ Snake feat. MØ.
# High audio features not found for track 'Lean On' by Major Lazer & DJ Snake feat. MØ.
# Got low audio features for track 'Astronaut' by Sido feat. Andreas Bourani.
# Got high audio features for track 'Astronaut' by Sido feat. Andreas Bourani.
# Got low audio features for track 'Hello' by Adele.
# Got high audio features for track 'Hello' by Adele.
# AcousticBrainz error for MBID low-level cb555502-3617-4929-8091-4763ccac2fd8: HTTP 404
# AcousticBrainz error for MBID high-level cb555502-3617-4929-8091-4763ccac2fd8: HTTP 404
# Low audio features not found for track 'Sugar' by Robin Schulz feat. Francesco Yates.
# High audio features not found for track 'Sugar' by Robin Schulz feat. Francesco Yates.
# AcousticBrainz error for MBID low-level 0c594ffe-4be7-4750-9f48-2f077fd7f506: HTTP 404
# AcousticBrainz error for MBID high-level 0c594ffe-4be7-4750-9f48-2f077fd7f506: HTTP 404
# Low audio features not found for track 'See You Again' by Wiz Khalifa feat. Charlie Puth.
# High audio features not found for track 'See You Again' by Wiz Khalifa feat. Charlie Puth.
# AcousticBrainz error for MBID low-level b2b0a26e-9985-49be-a112-6120927bcfe4: HTTP 404
# AcousticBrainz error for MBID high-level b2b0a26e-9985-49be-a112-6120927bcfe4: HTTP 404
# Low audio features not found for track 'Firestone' by Kygo feat. Conrad.
# High audio features not found for track 'Firestone' by Kygo feat. Conrad.
# AcousticBrainz error for MBID low-level cb571a6a-2df2-48f3-8d12-494f083e686c: HTTP 404
# AcousticBrainz error for MBID high-level cb571a6a-2df2-48f3-8d12-494f083e686c: HTTP 404
# Low audio features not found for track 'Wolke 4' by Philipp Dittberner & Marv.
# High audio features not found for track 'Wolke 4' by Philipp Dittberner & Marv.
# AcousticBrainz error for MBID low-level 0f3b9c63-5091-4979-b909-b1772fbaa818: HTTP 404
# AcousticBrainz error for MBID high-level 0f3b9c63-5091-4979-b909-b1772fbaa818: HTTP 404
# Low audio features not found for track 'Lieblingsmensch' by Namika.
# High audio features not found for track 'Lieblingsmensch' by Namika.
# AcousticBrainz error for MBID low-level 55217845-60d5-48dc-bbcb-a37ed8bb9784: HTTP 404
# AcousticBrainz error for MBID high-level 55217845-60d5-48dc-bbcb-a37ed8bb9784: HTTP 404
# Low audio features not found for track 'Wie schön du bist' by Sarah Connor.
# High audio features not found for track 'Wie schön du bist' by Sarah Connor.
# AcousticBrainz error for MBID low-level ae7347f3-e3bb-4c3e-b1fe-71acb740504c: HTTP 404
# AcousticBrainz error for MBID high-level ae7347f3-e3bb-4c3e-b1fe-71acb740504c: HTTP 404
# Low audio features not found for track 'Reality' by Lost Frequencies feat. Janieck Devy.
# High audio features not found for track 'Reality' by Lost Frequencies feat. Janieck Devy.
# AcousticBrainz error for MBID low-level f349f55f-0dcb-40b6-b308-f2d139eadac3: HTTP 404
# AcousticBrainz error for MBID high-level f349f55f-0dcb-40b6-b308-f2d139eadac3: HTTP 404
# Low audio features not found for track 'Supergirl' by Anna Naklab feat. Alle Farben & Younotus.
# High audio features not found for track 'Supergirl' by Anna Naklab feat. Alle Farben & Younotus.
# AcousticBrainz error for MBID low-level ba875a38-27ff-4a50-bd4d-ad907ac3eab3: HTTP 404
# AcousticBrainz error for MBID high-level ba875a38-27ff-4a50-bd4d-ad907ac3eab3: HTTP 404
# Low audio features not found for track 'Want To Want Me' by Jason Derulo.
# High audio features not found for track 'Want To Want Me' by Jason Derulo.
# AcousticBrainz error for MBID low-level d6b15d8f-56bc-4f76-baac-0f4bc1ddf20e: HTTP 404
# AcousticBrainz error for MBID high-level d6b15d8f-56bc-4f76-baac-0f4bc1ddf20e: HTTP 404
# Low audio features not found for track 'Unter meiner Haut' by Gestört aber GeiL & Koby Funk feat. Wincent Weiss.
# High audio features not found for track 'Unter meiner Haut' by Gestört aber GeiL & Koby Funk feat. Wincent Weiss.
# AcousticBrainz error for MBID low-level 624b61c5-b145-4cfc-8297-0c26411d0adc: HTTP 404
# AcousticBrainz error for MBID high-level 624b61c5-b145-4cfc-8297-0c26411d0adc: HTTP 404
# Low audio features not found for track 'Photograph' by Ed Sheeran.
# High audio features not found for track 'Photograph' by Ed Sheeran.
# AcousticBrainz error for MBID low-level 4f59c054-b71b-42e0-8ab1-3a391dde0246: HTTP 404
# AcousticBrainz error for MBID high-level 4f59c054-b71b-42e0-8ab1-3a391dde0246: HTTP 404
# Low audio features not found for track 'Headlights' by Robin Schulz feat. Ilsey.
# High audio features not found for track 'Headlights' by Robin Schulz feat. Ilsey.
# AcousticBrainz error for MBID low-level 4fef9389-c7cd-4aa0-934d-8d2bd9997ebf: HTTP 404
# AcousticBrainz error for MBID high-level 4fef9389-c7cd-4aa0-934d-8d2bd9997ebf: HTTP 404
# Low audio features not found for track 'Stole The Show' by Kygo feat. Parson James.
# High audio features not found for track 'Stole The Show' by Kygo feat. Parson James.
# Got low audio features for track 'Don't Worry' by Madcon feat. Ray Dalton.
# Got high audio features for track 'Don't Worry' by Madcon feat. Ray Dalton.
# Got low audio features for track 'Uptown Funk!' by Mark Ronson feat. Bruno Mars.
# Got high audio features for track 'Uptown Funk!' by Mark Ronson feat. Bruno Mars.
# AcousticBrainz error for MBID low-level 02547d71-8b65-4b38-bafe-115fcb0ba4d8: HTTP 404
# AcousticBrainz error for MBID high-level 02547d71-8b65-4b38-bafe-115fcb0ba4d8: HTTP 404
# Low audio features not found for track 'Bye Bye' by Cro.
# High audio features not found for track 'Bye Bye' by Cro.
# AcousticBrainz error for MBID low-level dd422ec5-7d15-4d2b-8e62-2b56e9578523: HTTP 404
# AcousticBrainz error for MBID high-level dd422ec5-7d15-4d2b-8e62-2b56e9578523: HTTP 404
# Low audio features not found for track 'Geiles Leben' by Glasperlenspiel.
# High audio features not found for track 'Geiles Leben' by Glasperlenspiel.
# Got low audio features for track 'FourFiveSeconds' by Rihanna and Kanye West and Paul McCartney.
# Got high audio features for track 'FourFiveSeconds' by Rihanna and Kanye West and Paul McCartney.
# AcousticBrainz error for MBID low-level 139fbb3f-61b1-4c2a-8e0c-ff2bee105c3c: HTTP 404
# AcousticBrainz error for MBID high-level 139fbb3f-61b1-4c2a-8e0c-ff2bee105c3c: HTTP 404
# Low audio features not found for track 'Herz über Kopf' by Joris.
# High audio features not found for track 'Herz über Kopf' by Joris.
# Got low audio features for track 'So wie du bist' by MoTrip feat. Lary.
# Got high audio features for track 'So wie du bist' by MoTrip feat. Lary.
# Got low audio features for track 'How Deep Is Your Love' by Calvin Harris + Disciples.
# Got high audio features for track 'How Deep Is Your Love' by Calvin Harris + Disciples.
# Got low audio features for track 'The Hanging Tree' by James Newton Howard feat. Jennifer Lawrence.
# Got high audio features for track 'The Hanging Tree' by James Newton Howard feat. Jennifer Lawrence.
# AcousticBrainz error for MBID low-level 5210ea81-9ad3-4f38-84ef-08ddb57a84c1: HTTP 404
# AcousticBrainz error for MBID high-level 5210ea81-9ad3-4f38-84ef-08ddb57a84c1: HTTP 404
# Low audio features not found for track 'Take Me To Church' by Hozier.
# High audio features not found for track 'Take Me To Church' by Hozier.
# AcousticBrainz error for MBID low-level 3ef5319e-b502-41c4-a480-f93f3781a3db: HTTP 404
# AcousticBrainz error for MBID high-level 3ef5319e-b502-41c4-a480-f93f3781a3db: HTTP 404
# Low audio features not found for track 'Intoxicated' by Martin Solveig & GTA.
# High audio features not found for track 'Intoxicated' by Martin Solveig & GTA.
# AcousticBrainz error for MBID low-level 3ea8e8b4-8b53-47c0-b996-3aab5623cd16: HTTP 404
# AcousticBrainz error for MBID high-level 3ea8e8b4-8b53-47c0-b996-3aab5623cd16: HTTP 404
# Low audio features not found for track 'Waiting For Love' by Avicii.
# High audio features not found for track 'Waiting For Love' by Avicii.
# AcousticBrainz error for MBID low-level 40d3b6ad-7c3f-4584-b1cc-0bb9a3800934: HTTP 404
# AcousticBrainz error for MBID high-level 40d3b6ad-7c3f-4584-b1cc-0bb9a3800934: HTTP 404
# Low audio features not found for track 'Hold Back The River' by James Bay.
# High audio features not found for track 'Hold Back The River' by James Bay.
# Got low audio features for track 'Hey Mama' by David Guetta feat. Nicki Minaj & Afrojack.
# Got high audio features for track 'Hey Mama' by David Guetta feat. Nicki Minaj & Afrojack.
# No MBID for track 'Shut Up + Dance' by Walk The Moon
# AcousticBrainz error for MBID low-level 397ae99e-8994-4213-b8bd-31e227b35bf5: HTTP 404
# AcousticBrainz error for MBID high-level 397ae99e-8994-4213-b8bd-31e227b35bf5: HTTP 404
# Low audio features not found for track 'Flash mich' by Mark Forster.
# High audio features not found for track 'Flash mich' by Mark Forster.
# Got low audio features for track 'Avenir' by Louane.
# Got high audio features for track 'Avenir' by Louane.
# AcousticBrainz error for MBID low-level 11056095-76a0-4b2b-8e71-5adcd6b3a8b5: HTTP 404
# AcousticBrainz error for MBID high-level 11056095-76a0-4b2b-8e71-5adcd6b3a8b5: HTTP 404
# Low audio features not found for track 'King' by Years & Years.
# High audio features not found for track 'King' by Years & Years.
# AcousticBrainz error for MBID low-level bbd91cae-d00f-4d8b-b2c8-d15a94784d16: HTTP 404
# AcousticBrainz error for MBID high-level bbd91cae-d00f-4d8b-b2c8-d15a94784d16: HTTP 404
# Low audio features not found for track 'Goodbye' by Feder feat. Lyse.
# High audio features not found for track 'Goodbye' by Feder feat. Lyse.
# AcousticBrainz error for MBID low-level 232d0fae-a373-4f40-9bef-08eceed8f290: HTTP 404
# AcousticBrainz error for MBID high-level 232d0fae-a373-4f40-9bef-08eceed8f290: HTTP 404
# Low audio features not found for track 'Outside' by Calvin Harris feat. Ellie Goulding.
# High audio features not found for track 'Outside' by Calvin Harris feat. Ellie Goulding.
# AcousticBrainz error for MBID low-level 1039280f-2c94-497b-9304-420b01d7b3ad: HTTP 404
# AcousticBrainz error for MBID high-level 1039280f-2c94-497b-9304-420b01d7b3ad: HTTP 404
# Low audio features not found for track 'El perdón' by Nicky Jam & Enrique Iglesias.
# High audio features not found for track 'El perdón' by Nicky Jam & Enrique Iglesias.
# AcousticBrainz error for MBID low-level 9df68257-6ce6-4180-92a8-e7077ab1ae0a: HTTP 404
# AcousticBrainz error for MBID high-level 9df68257-6ce6-4180-92a8-e7077ab1ae0a: HTTP 404
# Low audio features not found for track 'What Do You Mean?' by Justin Bieber.
# High audio features not found for track 'What Do You Mean?' by Justin Bieber.
# AcousticBrainz error for MBID low-level ae66d088-1801-4258-b771-a63d67cfd993: HTTP 404
# AcousticBrainz error for MBID high-level ae66d088-1801-4258-b771-a63d67cfd993: HTTP 404
# Low audio features not found for track 'Thinking Out Loud' by Ed Sheeran.
# High audio features not found for track 'Thinking Out Loud' by Ed Sheeran.
# Got low audio features for track 'Ghost Town' by Adam Lambert.
# Got high audio features for track 'Ghost Town' by Adam Lambert.
# AcousticBrainz error for MBID low-level 3ec8d0ea-f1f9-4a4a-91b8-1c402dc35741: HTTP 404
# AcousticBrainz error for MBID high-level 3ec8d0ea-f1f9-4a4a-91b8-1c402dc35741: HTTP 404
# Low audio features not found for track 'Walk' by Kwabs.
# High audio features not found for track 'Walk' by Kwabs.
# AcousticBrainz error for MBID low-level 39757c16-d84d-4537-a23a-be780e2b7e71: HTTP 404
# AcousticBrainz error for MBID high-level 39757c16-d84d-4537-a23a-be780e2b7e71: HTTP 404
# Low audio features not found for track 'Auf anderen Wegen' by Andreas Bourani.
# High audio features not found for track 'Auf anderen Wegen' by Andreas Bourani.
# AcousticBrainz error for MBID low-level 34af47ff-4feb-4aca-aa78-5ef5ab80c747: HTTP 404
# AcousticBrainz error for MBID high-level 34af47ff-4feb-4aca-aa78-5ef5ab80c747: HTTP 404
# Low audio features not found for track 'Can't Feel My Face' by The Weeknd.
# High audio features not found for track 'Can't Feel My Face' by The Weeknd.
# Got low audio features for track 'Locked Away' by R. City feat. Adam Levine.
# Got high audio features for track 'Locked Away' by R. City feat. Adam Levine.
# Got low audio features for track 'Worth It' by Fifth Harmony feat. Kid Ink.
# Got high audio features for track 'Worth It' by Fifth Harmony feat. Kid Ink.
# AcousticBrainz error for MBID low-level 6687491c-05b5-4e03-9f5d-6679a080fc2c: HTTP 404
# AcousticBrainz error for MBID high-level 6687491c-05b5-4e03-9f5d-6679a080fc2c: HTTP 404
# Low audio features not found for track 'Atemlos durch die Nacht' by Helene Fischer.
# High audio features not found for track 'Atemlos durch die Nacht' by Helene Fischer.
# AcousticBrainz error for MBID low-level 0ecf34a5-fedb-4eb3-a4ec-8c3cae3d2a92: HTTP 404
# AcousticBrainz error for MBID high-level 0ecf34a5-fedb-4eb3-a4ec-8c3cae3d2a92: HTTP 404
# Low audio features not found for track 'Ich will nur dass du weißt' by SDP feat. Adel Tawil.
# High audio features not found for track 'Ich will nur dass du weißt' by SDP feat. Adel Tawil.
# AcousticBrainz error for MBID low-level 336810fb-be64-487c-a9f7-41db19fc0615: HTTP 404
# AcousticBrainz error for MBID high-level 336810fb-be64-487c-a9f7-41db19fc0615: HTTP 404
# Low audio features not found for track 'Sorry' by Justin Bieber.
# High audio features not found for track 'Sorry' by Justin Bieber.
# AcousticBrainz error for MBID low-level ff5af0c7-3dda-4875-af13-586937bbb33a: HTTP 404
# AcousticBrainz error for MBID high-level ff5af0c7-3dda-4875-af13-586937bbb33a: HTTP 404
# Low audio features not found for track 'Wish You Were Mine' by Philip George.
# High audio features not found for track 'Wish You Were Mine' by Philip George.
# AcousticBrainz error for MBID low-level be6f7f80-844f-4f25-b9fe-9d062422247f: HTTP 404
# AcousticBrainz error for MBID high-level be6f7f80-844f-4f25-b9fe-9d062422247f: HTTP 404
# Low audio features not found for track 'The Hills' by The Weeknd.
# High audio features not found for track 'The Hills' by The Weeknd.
# AcousticBrainz error for MBID low-level 6f6b0791-86de-442d-8ca6-e151d7f814be: HTTP 404
# AcousticBrainz error for MBID high-level 6f6b0791-86de-442d-8ca6-e151d7f814be: HTTP 404
# Low audio features not found for track 'Book Of Love' by Felix Jaehn feat. Polina.
# High audio features not found for track 'Book Of Love' by Felix Jaehn feat. Polina.
# AcousticBrainz error for MBID low-level 3bc2767b-6856-49ec-8b9b-fc69df91bb6f: HTTP 404
# AcousticBrainz error for MBID high-level 3bc2767b-6856-49ec-8b9b-fc69df91bb6f: HTTP 404
# Low audio features not found for track 'Lush Life' by Zara Larsson.
# High audio features not found for track 'Lush Life' by Zara Larsson.
# Got low audio features for track 'G.D.F.R.' by Flo Rida feat. Sage The Gemini & Lookas.
# Got high audio features for track 'G.D.F.R.' by Flo Rida feat. Sage The Gemini & Lookas.
# AcousticBrainz error for MBID low-level 4846d476-6e79-4000-973c-7f978a6f6b50: HTTP 404
# AcousticBrainz error for MBID high-level 4846d476-6e79-4000-973c-7f978a6f6b50: HTTP 404
# Low audio features not found for track 'Sun Goes Down' by Robin Schulz feat. Jasmine Thompson.
# High audio features not found for track 'Sun Goes Down' by Robin Schulz feat. Jasmine Thompson.
# AcousticBrainz error for MBID low-level 31b5d6fc-7f32-4bec-837d-0cd0aa8afca5: HTTP 404
# AcousticBrainz error for MBID high-level 31b5d6fc-7f32-4bec-837d-0cd0aa8afca5: HTTP 404
# Low audio features not found for track 'Five More Hours' by Deorro x Chris Brown.
# High audio features not found for track 'Five More Hours' by Deorro x Chris Brown.
# Got low audio features for track 'Bills' by LunchMoney Lewis.
# Got high audio features for track 'Bills' by LunchMoney Lewis.
# Got low audio features for track 'I'm An Albatraoz' by AronChupa.
# Got high audio features for track 'I'm An Albatraoz' by AronChupa.
# Got low audio features for track 'Easy Love' by Sigala.
# Got high audio features for track 'Easy Love' by Sigala.
# Got low audio features for track 'Cool Kids' by Echosmith.
# Got high audio features for track 'Cool Kids' by Echosmith.
# AcousticBrainz error for MBID low-level bf7f3909-b9e5-4db1-9edd-e429108f5f91: HTTP 404
# AcousticBrainz error for MBID high-level bf7f3909-b9e5-4db1-9edd-e429108f5f91: HTTP 404
# Low audio features not found for track 'All Of Me' by John Legend.
# High audio features not found for track 'All Of Me' by John Legend.
# AcousticBrainz error for MBID low-level 9ba8c60e-d743-414f-91ea-abe861e29866: HTTP 404
# AcousticBrainz error for MBID high-level 9ba8c60e-d743-414f-91ea-abe861e29866: HTTP 404
# Low audio features not found for track 'Break The Rules' by Charli XCX.
# High audio features not found for track 'Break The Rules' by Charli XCX.
# AcousticBrainz error for MBID low-level 3090f4af-1311-4819-a07f-1b1a26fe68e9: HTTP 404
# AcousticBrainz error for MBID high-level 3090f4af-1311-4819-a07f-1b1a26fe68e9: HTTP 404
# Low audio features not found for track 'I Really Like You' by Carly Rae Jepsen.
# High audio features not found for track 'I Really Like You' by Carly Rae Jepsen.
# AcousticBrainz error for MBID low-level d7f161e5-55ef-40b3-a134-6ffe3074de65: HTTP 404
# AcousticBrainz error for MBID high-level d7f161e5-55ef-40b3-a134-6ffe3074de65: HTTP 404
# Low audio features not found for track 'Dangerous' by David Guetta feat. Sam Martin.
# High audio features not found for track 'Dangerous' by David Guetta feat. Sam Martin.
# AcousticBrainz error for MBID low-level 63dfd251-0b00-4e62-ad75-3ce2a2369e08: HTTP 404
# AcousticBrainz error for MBID high-level 63dfd251-0b00-4e62-ad75-3ce2a2369e08: HTTP 404
# Low audio features not found for track 'Lips Are Movin' by Meghan Trainor.
# High audio features not found for track 'Lips Are Movin' by Meghan Trainor.
# AcousticBrainz error for MBID low-level 5bb25c16-9607-4691-997b-c10ad1b44401: HTTP 404
# AcousticBrainz error for MBID high-level 5bb25c16-9607-4691-997b-c10ad1b44401: HTTP 404
# Low audio features not found for track 'Traffic Lights' by Lena.
# High audio features not found for track 'Traffic Lights' by Lena.
# AcousticBrainz error for MBID low-level bf4d9be9-57e4-49b7-8ef4-3ab6c742529a: HTTP 404
# AcousticBrainz error for MBID high-level bf4d9be9-57e4-49b7-8ef4-3ab6c742529a: HTTP 404
# Low audio features not found for track 'Catch & Release (Deepend Remix)' by Matt Simons.
# High audio features not found for track 'Catch & Release (Deepend Remix)' by Matt Simons.
# AcousticBrainz error for MBID low-level d6112bd1-55c0-49b5-a359-4966d43680f9: HTTP 404
# AcousticBrainz error for MBID high-level d6112bd1-55c0-49b5-a359-4966d43680f9: HTTP 404
# Low audio features not found for track 'Wild & Free' by Lena.
# High audio features not found for track 'Wild & Free' by Lena.
# Got low audio features for track 'Up' by Olly Murs feat. Demi Lovato.
# Got high audio features for track 'Up' by Olly Murs feat. Demi Lovato.
# AcousticBrainz error for MBID low-level 30b7395a-0ca4-4c0a-9ae5-d4cdf8e710ef: HTTP 404
# AcousticBrainz error for MBID high-level 30b7395a-0ca4-4c0a-9ae5-d4cdf8e710ef: HTTP 404
# Low audio features not found for track 'Ayo' by Chris Brown x Tyga.
# High audio features not found for track 'Ayo' by Chris Brown x Tyga.
# AcousticBrainz error for MBID low-level 1ef120a9-8c6a-4dc9-a5cc-5c27b6882d0e: HTTP 404
# AcousticBrainz error for MBID high-level 1ef120a9-8c6a-4dc9-a5cc-5c27b6882d0e: HTTP 404
# Low audio features not found for track 'Where Are Ü Now' by Skrillex & Diplo feat. Justin Bieber.
# High audio features not found for track 'Where Are Ü Now' by Skrillex & Diplo feat. Justin Bieber.
# AcousticBrainz error for MBID low-level c673c75c-a706-477d-8557-ef3b3acbb5b9: HTTP 404
# AcousticBrainz error for MBID high-level c673c75c-a706-477d-8557-ef3b3acbb5b9: HTTP 404
# Low audio features not found for track 'I Don't Like It, I Love It' by Flo Rida feat. Robin Thicke & Verdine White.
# High audio features not found for track 'I Don't Like It, I Love It' by Flo Rida feat. Robin Thicke & Verdine White.
# AcousticBrainz error for MBID low-level 3a34b305-00ae-4ece-97d1-12dd69a49ba2: HTTP 404
# AcousticBrainz error for MBID high-level 3a34b305-00ae-4ece-97d1-12dd69a49ba2: HTTP 404
# Low audio features not found for track 'Auf uns' by Andreas Bourani.
# High audio features not found for track 'Auf uns' by Andreas Bourani.
# Got low audio features for track 'Marvin Gaye' by Charlie Puth feat. Meghan Trainor.
# Got high audio features for track 'Marvin Gaye' by Charlie Puth feat. Meghan Trainor.
# AcousticBrainz error for MBID low-level 8f9b8bd9-7d34-45db-a7ad-20e19ab7b2db: HTTP 404
# AcousticBrainz error for MBID high-level 8f9b8bd9-7d34-45db-a7ad-20e19ab7b2db: HTTP 404
# Low audio features not found for track 'Hula Hoop' by Omi.
# High audio features not found for track 'Hula Hoop' by Omi.
# AcousticBrainz error for MBID low-level 80f8eae6-7787-4595-9e44-39ccf2898b0e: HTTP 404
# AcousticBrainz error for MBID high-level 80f8eae6-7787-4595-9e44-39ccf2898b0e: HTTP 404
# Low audio features not found for track 'Alles brennt' by Johannes Oerding.
# High audio features not found for track 'Alles brennt' by Johannes Oerding.
# AcousticBrainz error for MBID low-level eeb6c1f1-8f57-495a-bb38-f5446bcb34ae: HTTP 404
# AcousticBrainz error for MBID high-level eeb6c1f1-8f57-495a-bb38-f5446bcb34ae: HTTP 404
# Low audio features not found for track 'Blank Space' by Taylor Swift.
# High audio features not found for track 'Blank Space' by Taylor Swift.
# AcousticBrainz error for MBID low-level 6df43485-06bb-47f3-b615-ee0aaa628d6d: HTTP 404
# AcousticBrainz error for MBID high-level 6df43485-06bb-47f3-b615-ee0aaa628d6d: HTTP 404
# Low audio features not found for track 'The Nights' by Avicii.
# High audio features not found for track 'The Nights' by Avicii.
# Got low audio features for track 'Fade Out Lines' by The Avener.
# Got high audio features for track 'Fade Out Lines' by The Avener.
# Got low audio features for track 'What I Did For Love' by David Guetta feat. Emeli Sandé.
# Got high audio features for track 'What I Did For Love' by David Guetta feat. Emeli Sandé.
# AcousticBrainz error for MBID low-level 48c14ec4-70e5-43d1-873a-41bb5efa0fd6: HTTP 404
# AcousticBrainz error for MBID high-level 48c14ec4-70e5-43d1-873a-41bb5efa0fd6: HTTP 404
# Low audio features not found for track 'Riva (Restart The Game)' by Klingande feat. Broken Back.
# High audio features not found for track 'Riva (Restart The Game)' by Klingande feat. Broken Back.
# AcousticBrainz error for MBID low-level a94775bb-4c7d-4a91-ab01-53b09128f760: HTTP 404
# AcousticBrainz error for MBID high-level a94775bb-4c7d-4a91-ab01-53b09128f760: HTTP 404
# Low audio features not found for track 'You Know You Like It' by DJ Snake & AlunaGeorge.
# High audio features not found for track 'You Know You Like It' by DJ Snake & AlunaGeorge.
# Got low audio features for track 'On My Mind' by Ellie Goulding.
# Got high audio features for track 'On My Mind' by Ellie Goulding.
# AcousticBrainz error for MBID low-level aef6eb90-dc11-4285-aa3d-6d045a8e62fe: HTTP 404
# AcousticBrainz error for MBID high-level aef6eb90-dc11-4285-aa3d-6d045a8e62fe: HTTP 404
# Low audio features not found for track 'Holiday' by DJ Antoine feat. Akon.
# High audio features not found for track 'Holiday' by DJ Antoine feat. Akon.
# AcousticBrainz error for MBID low-level b36d5376-f578-4810-bddf-d3206f0cc3df: HTTP 404
# AcousticBrainz error for MBID high-level b36d5376-f578-4810-bddf-d3206f0cc3df: HTTP 404
# Low audio features not found for track 'Ich & du' by Gestört aber GeiL feat. Sebastian Hämer.
# High audio features not found for track 'Ich & du' by Gestört aber GeiL feat. Sebastian Hämer.
# Got low audio features for track 'Earned It' by The Weeknd.
# Got high audio features for track 'Earned It' by The Weeknd.
# Got low audio features for track 'Bauch und Kopf' by Mark Forster.
# Got high audio features for track 'Bauch und Kopf' by Mark Forster.
# AcousticBrainz error for MBID low-level df08d547-62bb-4f06-b37b-21f913ad50ff: HTTP 404
# AcousticBrainz error for MBID high-level df08d547-62bb-4f06-b37b-21f913ad50ff: HTTP 404
# Low audio features not found for track 'El mismo sol' by Alvaro Soler.
# High audio features not found for track 'El mismo sol' by Alvaro Soler.
# AcousticBrainz error for MBID low-level d149ccee-28bc-4cf8-a2a2-ce0c979b3304: HTTP 404
# AcousticBrainz error for MBID high-level d149ccee-28bc-4cf8-a2a2-ce0c979b3304: HTTP 404
# Low audio features not found for track 'Lucifer' by XOV.
# High audio features not found for track 'Lucifer' by XOV.
# AcousticBrainz error for MBID low-level c0af0680-0700-4e4d-81ff-824835c4bac3: HTTP 404
# AcousticBrainz error for MBID high-level c0af0680-0700-4e4d-81ff-824835c4bac3: HTTP 404
# Low audio features not found for track 'Show Me Love' by Robin Schulz & J.U.D.G.E..
# High audio features not found for track 'Show Me Love' by Robin Schulz & J.U.D.G.E..
# AcousticBrainz error for MBID low-level 5b056aea-3567-48ca-b6b9-6c78eb29728d: HTTP 404
# AcousticBrainz error for MBID high-level 5b056aea-3567-48ca-b6b9-6c78eb29728d: HTTP 404
# Low audio features not found for track 'Pray To God' by Calvin Harris feat. Haim.
# High audio features not found for track 'Pray To God' by Calvin Harris feat. Haim.
# AcousticBrainz error for MBID low-level 3eaaee3b-595e-47f4-aa1d-d55f29036936: HTTP 404
# AcousticBrainz error for MBID high-level 3eaaee3b-595e-47f4-aa1d-d55f29036936: HTTP 404
# Low audio features not found for track 'Heartbeat Song' by Kelly Clarkson.
# High audio features not found for track 'Heartbeat Song' by Kelly Clarkson.
# Got low audio features for track 'Time Of Our Lives' by Pitbull & Ne-Yo.
# Got high audio features for track 'Time Of Our Lives' by Pitbull & Ne-Yo.
# Got low audio features for track 'Hurra die Welt geht unter' by K.I.Z. feat. Henning May.
# Got high audio features for track 'Hurra die Welt geht unter' by K.I.Z. feat. Henning May.
# AcousticBrainz error for MBID low-level f127ad36-d371-4ec3-a6e8-2f2bac5b2eca: HTTP 404
# AcousticBrainz error for MBID high-level f127ad36-d371-4ec3-a6e8-2f2bac5b2eca: HTTP 404
# Low audio features not found for track 'Love Yourself' by Justin Bieber.
# High audio features not found for track 'Love Yourself' by Justin Bieber.
# Got low audio features for track 'Au revoir' by Mark Forster feat. Sido.
# Got high audio features for track 'Au revoir' by Mark Forster feat. Sido.
# AcousticBrainz error for MBID low-level f6f8f236-2898-4fc9-af3a-28c0b682b944: HTTP 404
# AcousticBrainz error for MBID high-level f6f8f236-2898-4fc9-af3a-28c0b682b944: HTTP 404
# Low audio features not found for track 'Prayer In C (Robin Schulz Remix)' by Lilly Wood & The Prick and Robin Schulz.
# High audio features not found for track 'Prayer In C (Robin Schulz Remix)' by Lilly Wood & The Prick and Robin Schulz.

# %%
# Add the audio features results to a new column in the DataFrame
df_2015["AudioFeatures_low"] = low_audio_features_list
df_2015["AudioFeatures_high"] = high_audio_features_list

df_2015.head()
# Out:
#   Position                              Artist  \
# 0        1                                 Omi
# 1        2                    Lost Frequencies
# 2        3  Felix Jaehn feat. Jasmine Thompson
# 3        4                      Ellie Goulding
# 4        5     Major Lazer & DJ Snake feat. MØ
#
#                              Title                                  MBID  \
# 0  Cheerleader (Felix Jaehn Remix)  d15b0f43-ac17-4c01-95f1-687c5456093a
# 1                  Are You With Me  a88cea49-b308-49a2-abd3-421c2aef0c80
# 2   Ain't Nobody (Loves Me Better)  bad77138-96a6-4b39-be33-2e5b0dd2a838
# 3              Love Me Like You Do  161efdaf-9742-4e82-97df-7f0c4e59cbc3
# 4                          Lean On  1e3a21a1-86a8-4cef-82be-b989c20ab113
#
#                                    AudioFeatures_low  \
# 0                                               None
# 1  {'lowlevel': {'average_loudness': 0.7344310879...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                   AudioFeatures_high
# 0                                               None
# 1  {'highlevel': {'danceability': {'all': {'dance...
# 2                                               None
# 3                                               None
# 4                                               None

# %%
low_found_count = df_2015['AudioFeatures_low'].notna().sum()
high_found_count = df_2015['AudioFeatures_high'].notna().sum()
total_count = len(df_2015)
print(f"Finished processing {year}. Found low features for {low_found_count} and high for {high_found_count} out of {total_count} tracks.\n")
# Out:
# Finished processing 2016. Found low features for 30 and high for 30 out of 100 tracks.

# %%
df_2015.to_csv("tracks_audio_features_2015.csv", index=False, encoding="utf-8")
print("Data with audio features saved as 'tracks_audio_features_2015.csv'.")
# Out:
# Data with audio features saved as 'tracks_audio_features_2015.csv'.

# %% [markdown]
# ### Step 3
# After that, using the MBID, I retrieved the audio features for each track by using the API functions of the acousticbrainz.org website.

# %%
all_years_audio_features = []

for year in range(2016, 2023):
    df_year = mbid_yearly[year].copy() 
    low_audio_features_list = []     
    high_audio_features_list = []     
    
    print(f"Processing year {year}...")
    for idx, row in df_year.iterrows():
        mbid = row.get("MBID")
        if mbid:
            features_low = search_audio_features(mbid)
            features_high = search_high_audio_features(mbid)
            if features_low is not None:
                print(f"Got low audio features for track '{row['Title']}' by {row['Artist']} in {year}.")
            else:
                print(f"Low audio features not found for track '{row['Title']}' by {row['Artist']} in {year}.")
            if features_high is not None:
                print(f"Got high audio features for track '{row['Title']}' by {row['Artist']} in {year}.")
            else:
                print(f"High audio features not found for track '{row['Title']}' by {row['Artist']} in {year}.")
        else:
            print(f"No MBID for track '{row['Title']}' by {row['Artist']} in {year}.")
            features_low = None
            features_high = None
        
        low_audio_features_list.append(features_low)
        high_audio_features_list.append(features_high)
      
        time.sleep(1)
        
    df_year["Low_AudioFeatures"] = low_audio_features_list
    df_year["High_AudioFeatures"] = high_audio_features_list
    df_year["Year"] = year
    

    all_years_audio_features.append(df_year)


final_df = pd.concat(all_years_audio_features, ignore_index=True)

final_df.to_csv("tracks_audio_features_2016_2022.csv", index=False, encoding="utf-8")
print("Combined results saved to 'tracks_audio_features_2016_2022.csv'.")
# Out:
# Processing year 2016...
# Got low audio features for track 'Faded' by Alan Walker in 2016.
# Got high audio features for track 'Faded' by Alan Walker in 2016.
# AcousticBrainz error for MBID low-level 40eda342-9655-45f9-a620-97db83ea8bad: HTTP 404
# AcousticBrainz error for MBID high-level 40eda342-9655-45f9-a620-97db83ea8bad: HTTP 404
# Low audio features not found for track 'Die immer lacht' by Stereoact feat. Kerstin Ott in 2016.
# High audio features not found for track 'Die immer lacht' by Stereoact feat. Kerstin Ott in 2016.
# AcousticBrainz error for MBID low-level 7a6e19a3-41a2-46d9-8d25-9d7cb5c2363c: HTTP 404
# AcousticBrainz error for MBID high-level 7a6e19a3-41a2-46d9-8d25-9d7cb5c2363c: HTTP 404
# Low audio features not found for track 'Cheap Thrills' by Sia feat. Sean Paul in 2016.
# High audio features not found for track 'Cheap Thrills' by Sia feat. Sean Paul in 2016.
# AcousticBrainz error for MBID low-level f8564d8c-eb2a-48be-83ab-618fc44a647d: HTTP 404
# AcousticBrainz error for MBID high-level f8564d8c-eb2a-48be-83ab-618fc44a647d: HTTP 404
# Low audio features not found for track 'Don't Be So Shy (Filatov & Karas Remix)' by Imany in 2016.
# High audio features not found for track 'Don't Be So Shy (Filatov & Karas Remix)' by Imany in 2016.
# Got low audio features for track 'One Dance' by Drake feat. Wizkid & Kyla in 2016.
# Got high audio features for track 'One Dance' by Drake feat. Wizkid & Kyla in 2016.
# AcousticBrainz error for MBID low-level a21f0ca9-261f-40bf-a2b0-8e6a482b4ea8: HTTP 404
# AcousticBrainz error for MBID high-level a21f0ca9-261f-40bf-a2b0-8e6a482b4ea8: HTTP 404
# Low audio features not found for track 'This Girl' by Kungs vs. Cookin' On 3 Burners in 2016.
# High audio features not found for track 'This Girl' by Kungs vs. Cookin' On 3 Burners in 2016.
# AcousticBrainz error for MBID low-level 3e68c583-6ec5-440f-9079-2f270756535b: HTTP 404
# AcousticBrainz error for MBID high-level 3e68c583-6ec5-440f-9079-2f270756535b: HTTP 404
# Low audio features not found for track 'Don't Let Me Down' by The Chainsmokers feat. Daya in 2016.
# High audio features not found for track 'Don't Let Me Down' by The Chainsmokers feat. Daya in 2016.
# AcousticBrainz error for MBID low-level 161c8971-a425-4488-a167-b68ad7a52ed9: HTTP 404
# AcousticBrainz error for MBID high-level 161c8971-a425-4488-a167-b68ad7a52ed9: HTTP 404
# Low audio features not found for track 'Stressed Out' by Twenty One Pilots in 2016.
# High audio features not found for track 'Stressed Out' by Twenty One Pilots in 2016.
# Got low audio features for track 'Human' by Rag'n'Bone Man in 2016.
# Got high audio features for track 'Human' by Rag'n'Bone Man in 2016.
# AcousticBrainz error for MBID low-level 724a69dc-6e30-4830-b8cc-f94085a8d505: HTTP 404
# AcousticBrainz error for MBID high-level 724a69dc-6e30-4830-b8cc-f94085a8d505: HTTP 404
# Low audio features not found for track 'Can't Stop The Feeling!' by Justin Timberlake in 2016.
# High audio features not found for track 'Can't Stop The Feeling!' by Justin Timberlake in 2016.
# Got low audio features for track 'I Took A Pill In Ibiza' by Mike Posner in 2016.
# Got high audio features for track 'I Took A Pill In Ibiza' by Mike Posner in 2016.
# AcousticBrainz error for MBID low-level f127ad36-d371-4ec3-a6e8-2f2bac5b2eca: HTTP 404
# AcousticBrainz error for MBID high-level f127ad36-d371-4ec3-a6e8-2f2bac5b2eca: HTTP 404
# Low audio features not found for track 'Love Yourself' by Justin Bieber in 2016.
# High audio features not found for track 'Love Yourself' by Justin Bieber in 2016.
# AcousticBrainz error for MBID low-level 5d1538f0-af74-45d8-affa-0aebd489a52b: HTTP 404
# AcousticBrainz error for MBID high-level 5d1538f0-af74-45d8-affa-0aebd489a52b: HTTP 404
# Low audio features not found for track 'Fast Car' by Jonas Blue feat. Dakota in 2016.
# High audio features not found for track 'Fast Car' by Jonas Blue feat. Dakota in 2016.
# AcousticBrainz error for MBID low-level 5d4d7efb-f46a-432f-aa55-1dda1211e6f7: HTTP 404
# AcousticBrainz error for MBID high-level 5d4d7efb-f46a-432f-aa55-1dda1211e6f7: HTTP 404
# Low audio features not found for track 'The Sound Of Silence' by Disturbed in 2016.
# High audio features not found for track 'The Sound Of Silence' by Disturbed in 2016.
# AcousticBrainz error for MBID low-level 855128d3-4295-4a70-ad61-910b370ad0ea: HTTP 404
# AcousticBrainz error for MBID high-level 855128d3-4295-4a70-ad61-910b370ad0ea: HTTP 404
# Low audio features not found for track 'Cold Water' by Major Lazer feat. Justin Bieber & MØ in 2016.
# High audio features not found for track 'Cold Water' by Major Lazer feat. Justin Bieber & MØ in 2016.
# AcousticBrainz error for MBID low-level 7933f18b-766a-44bf-93bd-46fbe85f29ec: HTTP 404
# AcousticBrainz error for MBID high-level 7933f18b-766a-44bf-93bd-46fbe85f29ec: HTTP 404
# Low audio features not found for track 'Let Me Love You' by DJ Snake feat. Justin Bieber in 2016.
# High audio features not found for track 'Let Me Love You' by DJ Snake feat. Justin Bieber in 2016.
# Got low audio features for track 'This Is What You Came For' by Calvin Harris feat. Rihanna in 2016.
# Got high audio features for track 'This Is What You Came For' by Calvin Harris feat. Rihanna in 2016.
# AcousticBrainz error for MBID low-level 3d6a21b3-3710-468f-a049-d1c5bee0863d: HTTP 404
# AcousticBrainz error for MBID high-level 3d6a21b3-3710-468f-a049-d1c5bee0863d: HTTP 404
# Low audio features not found for track 'Closer' by The Chainsmokers feat. Halsey in 2016.
# High audio features not found for track 'Closer' by The Chainsmokers feat. Halsey in 2016.
# AcousticBrainz error for MBID low-level bb9927e2-8996-4be6-bb5e-ee6bbaa93bdb: HTTP 404
# AcousticBrainz error for MBID high-level bb9927e2-8996-4be6-bb5e-ee6bbaa93bdb: HTTP 404
# Low audio features not found for track 'Me, Myself & I' by G-Eazy x Bebe Rexha in 2016.
# High audio features not found for track 'Me, Myself & I' by G-Eazy x Bebe Rexha in 2016.
# AcousticBrainz error for MBID low-level 7bc4ec80-3c68-4e7a-bc58-fa5cc2e9526f: HTTP 404
# AcousticBrainz error for MBID high-level 7bc4ec80-3c68-4e7a-bc58-fa5cc2e9526f: HTTP 404
# Low audio features not found for track 'Ain't Your Mama' by Jennifer Lopez in 2016.
# High audio features not found for track 'Ain't Your Mama' by Jennifer Lopez in 2016.
# Got low audio features for track 'Wir sind gross' by Mark Forster in 2016.
# Got high audio features for track 'Wir sind gross' by Mark Forster in 2016.
# AcousticBrainz error for MBID low-level ed429e45-ca92-4d70-ba45-aed911042a6a: HTTP 404
# AcousticBrainz error for MBID high-level ed429e45-ca92-4d70-ba45-aed911042a6a: HTTP 404
# Low audio features not found for track '7 Years' by Lukas Graham in 2016.
# High audio features not found for track '7 Years' by Lukas Graham in 2016.
# AcousticBrainz error for MBID low-level 28057e31-9841-415b-95ae-1674d4dcf7ee: HTTP 404
# AcousticBrainz error for MBID high-level 28057e31-9841-415b-95ae-1674d4dcf7ee: HTTP 404
# Low audio features not found for track 'Bonfire' by Felix Jaehn feat. Alma in 2016.
# High audio features not found for track 'Bonfire' by Felix Jaehn feat. Alma in 2016.
# AcousticBrainz error for MBID low-level 409eef7e-e80f-4d80-90b3-a27cf256f523: HTTP 404
# AcousticBrainz error for MBID high-level 409eef7e-e80f-4d80-90b3-a27cf256f523: HTTP 404
# Low audio features not found for track 'Treat You Better' by Shawn Mendes in 2016.
# High audio features not found for track 'Treat You Better' by Shawn Mendes in 2016.
# AcousticBrainz error for MBID low-level 52f0e20d-3e80-442e-915d-4016a62663bd: HTTP 404
# AcousticBrainz error for MBID high-level 52f0e20d-3e80-442e-915d-4016a62663bd: HTTP 404
# Low audio features not found for track 'Hulapalu' by Andreas Gabalier in 2016.
# High audio features not found for track 'Hulapalu' by Andreas Gabalier in 2016.
# AcousticBrainz error for MBID low-level eb9a7d5b-41cf-43e6-a9f5-6d15ddc4563a: HTTP 404
# AcousticBrainz error for MBID high-level eb9a7d5b-41cf-43e6-a9f5-6d15ddc4563a: HTTP 404
# Low audio features not found for track 'Please Tell Rosie' by Alle Farben feat. Younotus in 2016.
# High audio features not found for track 'Please Tell Rosie' by Alle Farben feat. Younotus in 2016.
# Got low audio features for track 'The Ocean' by Mike Perry feat. Shy Martin in 2016.
# Got high audio features for track 'The Ocean' by Mike Perry feat. Shy Martin in 2016.
# AcousticBrainz error for MBID low-level b8e2999b-6973-40b3-884c-740003d129ae: HTTP 404
# AcousticBrainz error for MBID high-level b8e2999b-6973-40b3-884c-740003d129ae: HTTP 404
# Low audio features not found for track 'Hymn For The Weekend' by Coldplay in 2016.
# High audio features not found for track 'Hymn For The Weekend' by Coldplay in 2016.
# AcousticBrainz error for MBID low-level 95f8588d-612f-4832-87a6-4aab65a46be6: HTTP 404
# AcousticBrainz error for MBID high-level 95f8588d-612f-4832-87a6-4aab65a46be6: HTTP 404
# Low audio features not found for track 'Light It Up (Remix)' by Major Lazer feat. Nyla & Fuse ODG in 2016.
# High audio features not found for track 'Light It Up (Remix)' by Major Lazer feat. Nyla & Fuse ODG in 2016.
# AcousticBrainz error for MBID low-level f8d1265c-b0a3-4683-af04-1c9ea808d70e: HTTP 404
# AcousticBrainz error for MBID high-level f8d1265c-b0a3-4683-af04-1c9ea808d70e: HTTP 404
# Low audio features not found for track 'Work From Home' by Fifth Harmony feat. Ty Dolla $ign in 2016.
# High audio features not found for track 'Work From Home' by Fifth Harmony feat. Ty Dolla $ign in 2016.
# AcousticBrainz error for MBID low-level 1107e8d1-2f91-4b69-994f-82c699d80e62: HTTP 404
# AcousticBrainz error for MBID high-level 1107e8d1-2f91-4b69-994f-82c699d80e62: HTTP 404
# Low audio features not found for track '80 Millionen' by Max Giesinger in 2016.
# High audio features not found for track '80 Millionen' by Max Giesinger in 2016.
# AcousticBrainz error for MBID low-level 0143f212-81c2-464d-b626-15e8cbd8f17d: HTTP 404
# AcousticBrainz error for MBID high-level 0143f212-81c2-464d-b626-15e8cbd8f17d: HTTP 404
# Low audio features not found for track 'Panda' by Desiigner in 2016.
# High audio features not found for track 'Panda' by Desiigner in 2016.
# AcousticBrainz error for MBID low-level 0972b23d-9817-49f1-b648-1010db86b70d: HTTP 404
# AcousticBrainz error for MBID high-level 0972b23d-9817-49f1-b648-1010db86b70d: HTTP 404
# Low audio features not found for track 'I Hate U, I Love U' by Gnash feat. Olivia O'Brien in 2016.
# High audio features not found for track 'I Hate U, I Love U' by Gnash feat. Olivia O'Brien in 2016.
# AcousticBrainz error for MBID low-level ce89ea60-ddc8-44eb-9575-c60b836c93a3: HTTP 404
# AcousticBrainz error for MBID high-level ce89ea60-ddc8-44eb-9575-c60b836c93a3: HTTP 404
# Low audio features not found for track 'Heathens' by Twenty One Pilots in 2016.
# High audio features not found for track 'Heathens' by Twenty One Pilots in 2016.
# AcousticBrainz error for MBID low-level 6d8c6513-3cd9-4784-bdf3-8df811605529: HTTP 404
# AcousticBrainz error for MBID high-level 6d8c6513-3cd9-4784-bdf3-8df811605529: HTTP 404
# Low audio features not found for track 'Stitches' by Shawn Mendes in 2016.
# High audio features not found for track 'Stitches' by Shawn Mendes in 2016.
# AcousticBrainz error for MBID low-level 2dc750ed-0e22-4c3c-9edf-dd4cfd1ab52f: HTTP 404
# AcousticBrainz error for MBID high-level 2dc750ed-0e22-4c3c-9edf-dd4cfd1ab52f: HTTP 404
# Low audio features not found for track 'Cake By The Ocean' by DNCE in 2016.
# High audio features not found for track 'Cake By The Ocean' by DNCE in 2016.
# AcousticBrainz error for MBID low-level 42a38f7f-e8ef-4520-8c55-acdf491fe27a: HTTP 404
# AcousticBrainz error for MBID high-level 42a38f7f-e8ef-4520-8c55-acdf491fe27a: HTTP 404
# Low audio features not found for track 'No Money' by Galantis in 2016.
# High audio features not found for track 'No Money' by Galantis in 2016.
# Got low audio features for track 'Ahnma' by Beginner feat. Gzuz & Gentleman in 2016.
# Got high audio features for track 'Ahnma' by Beginner feat. Gzuz & Gentleman in 2016.
# Got low audio features for track 'Stimme' by EFF in 2016.
# Got high audio features for track 'Stimme' by EFF in 2016.
# Got low audio features for track 'Geiles Leben' by Glasperlenspiel in 2016.
# Got high audio features for track 'Geiles Leben' by Glasperlenspiel in 2016.
# Got low audio features for track 'Holz' by 257ers in 2016.
# Got high audio features for track 'Holz' by 257ers in 2016.
# Got low audio features for track 'This One's For You' by David Guetta feat. Zara Larsson in 2016.
# Got high audio features for track 'This One's For You' by David Guetta feat. Zara Larsson in 2016.
# Got low audio features for track 'Work' by Rihanna feat. Drake in 2016.
# Got high audio features for track 'Work' by Rihanna feat. Drake in 2016.
# Got low audio features for track 'The Greatest' by Sia feat. Kendrick Lamar in 2016.
# Got high audio features for track 'The Greatest' by Sia feat. Kendrick Lamar in 2016.
# AcousticBrainz error for MBID low-level 2f28aebf-7be6-4195-b26f-989a2308d916: HTTP 404
# AcousticBrainz error for MBID high-level 2f28aebf-7be6-4195-b26f-989a2308d916: HTTP 404
# Low audio features not found for track 'Sex' by Cheat Codes x Kris Kross Amsterdam in 2016.
# High audio features not found for track 'Sex' by Cheat Codes x Kris Kross Amsterdam in 2016.
# No MBID for track 'Sucker For Pain' by Lil Wayne, Wiz Khalifa & Imagine Dragons feat. Logic, Ty Dolla $ign & X Ambassadors in 2016.
# AcousticBrainz error for MBID low-level 90fee432-08cc-4ad3-acfd-647acca76905: HTTP 404
# AcousticBrainz error for MBID high-level 90fee432-08cc-4ad3-acfd-647acca76905: HTTP 404
# Low audio features not found for track 'Palmen aus Plastik' by Bonez MC & RAF Camora in 2016.
# High audio features not found for track 'Palmen aus Plastik' by Bonez MC & RAF Camora in 2016.
# AcousticBrainz error for MBID low-level 336810fb-be64-487c-a9f7-41db19fc0615: HTTP 404
# AcousticBrainz error for MBID high-level 336810fb-be64-487c-a9f7-41db19fc0615: HTTP 404
# Low audio features not found for track 'Sorry' by Justin Bieber in 2016.
# High audio features not found for track 'Sorry' by Justin Bieber in 2016.
# AcousticBrainz error for MBID low-level b364d4ff-b8cf-41ed-8f8c-7551bc707b57: HTTP 404
# AcousticBrainz error for MBID high-level b364d4ff-b8cf-41ed-8f8c-7551bc707b57: HTTP 404
# Low audio features not found for track 'Starboy' by The Weeknd feat. Daft Punk in 2016.
# High audio features not found for track 'Starboy' by The Weeknd feat. Daft Punk in 2016.
# AcousticBrainz error for MBID low-level e42d264d-658e-42fc-acef-f571c975a2b3: HTTP 404
# AcousticBrainz error for MBID high-level e42d264d-658e-42fc-acef-f571c975a2b3: HTTP 404
# Low audio features not found for track 'Perfect Strangers' by Jonas Blue feat. JP. Cooper in 2016.
# High audio features not found for track 'Perfect Strangers' by Jonas Blue feat. JP. Cooper in 2016.
# AcousticBrainz error for MBID low-level 15d969e0-ed3a-48ce-a691-95c7bba2f3a9: HTTP 404
# AcousticBrainz error for MBID high-level 15d969e0-ed3a-48ce-a691-95c7bba2f3a9: HTTP 404
# Low audio features not found for track 'Sing Me To Sleep' by Alan Walker in 2016.
# High audio features not found for track 'Sing Me To Sleep' by Alan Walker in 2016.
# AcousticBrainz error for MBID low-level 18c339dd-4f19-44a3-b886-d91b5f024bb4: HTTP 404
# AcousticBrainz error for MBID high-level 18c339dd-4f19-44a3-b886-d91b5f024bb4: HTTP 404
# Low audio features not found for track 'Catch & Release (Deepend Remix)' by Matt Simons in 2016.
# High audio features not found for track 'Catch & Release (Deepend Remix)' by Matt Simons in 2016.
# Got low audio features for track 'Would I Lie To You' by David Guetta, Cedric Gervais & Chris Willis in 2016.
# Got high audio features for track 'Would I Lie To You' by David Guetta, Cedric Gervais & Chris Willis in 2016.
# AcousticBrainz error for MBID low-level 3bc2767b-6856-49ec-8b9b-fc69df91bb6f: HTTP 404
# AcousticBrainz error for MBID high-level 3bc2767b-6856-49ec-8b9b-fc69df91bb6f: HTTP 404
# Low audio features not found for track 'Lush Life' by Zara Larsson in 2016.
# High audio features not found for track 'Lush Life' by Zara Larsson in 2016.
# AcousticBrainz error for MBID low-level dba8ab92-1d66-4ba7-9462-5465b0926745: HTTP 404
# AcousticBrainz error for MBID high-level dba8ab92-1d66-4ba7-9462-5465b0926745: HTTP 404
# Low audio features not found for track 'Ohne mein Team' by Bonez MC & RAF Camora feat. Maxwell in 2016.
# High audio features not found for track 'Ohne mein Team' by Bonez MC & RAF Camora feat. Maxwell in 2016.
# AcousticBrainz error for MBID low-level 4e15d282-0833-470b-989e-ee73f06f9737: HTTP 404
# AcousticBrainz error for MBID high-level 4e15d282-0833-470b-989e-ee73f06f9737: HTTP 404
# Low audio features not found for track 'Home' by Topic feat. Nico Santos in 2016.
# High audio features not found for track 'Home' by Topic feat. Nico Santos in 2016.
# AcousticBrainz error for MBID low-level ad92d94f-9015-4088-a56b-60afd0d0400c: HTTP 404
# AcousticBrainz error for MBID high-level ad92d94f-9015-4088-a56b-60afd0d0400c: HTTP 404
# Low audio features not found for track 'Bonbon' by Era Istrefi in 2016.
# High audio features not found for track 'Bonbon' by Era Istrefi in 2016.
# AcousticBrainz error for MBID low-level 65ccef3f-1e3f-446a-9b3a-11acd794cc5b: HTTP 404
# AcousticBrainz error for MBID high-level 65ccef3f-1e3f-446a-9b3a-11acd794cc5b: HTTP 404
# Low audio features not found for track 'My Way' by Calvin Harris in 2016.
# High audio features not found for track 'My Way' by Calvin Harris in 2016.
# Got low audio features for track 'Rockabye' by Clean Bandit feat. Sean Paul & Anne-Marie in 2016.
# Got high audio features for track 'Rockabye' by Clean Bandit feat. Sean Paul & Anne-Marie in 2016.
# AcousticBrainz error for MBID low-level db611417-b2e9-41bb-94eb-c19281dedbed: HTTP 404
# AcousticBrainz error for MBID high-level db611417-b2e9-41bb-94eb-c19281dedbed: HTTP 404
# Low audio features not found for track 'In The Name Of Love' by Martin Garrix & Bebe Rexha in 2016.
# High audio features not found for track 'In The Name Of Love' by Martin Garrix & Bebe Rexha in 2016.
# AcousticBrainz error for MBID low-level 566f18b4-a21d-4eb3-bf3d-61e36a9cf172: HTTP 404
# AcousticBrainz error for MBID high-level 566f18b4-a21d-4eb3-bf3d-61e36a9cf172: HTTP 404
# Low audio features not found for track 'Ex's & Oh's' by Elle King in 2016.
# High audio features not found for track 'Ex's & Oh's' by Elle King in 2016.
# No MBID for track 'Duele el corazón' by Enrique Iglesias feat. Wisin in 2016.
# Got low audio features for track 'Final Song' by MØ in 2016.
# Got high audio features for track 'Final Song' by MØ in 2016.
# Got low audio features for track 'If I Were Sorry' by Frans in 2016.
# Got high audio features for track 'If I Were Sorry' by Frans in 2016.
# Got low audio features for track 'Too Good' by Drake feat. Rihanna in 2016.
# Got high audio features for track 'Too Good' by Drake feat. Rihanna in 2016.
# Got low audio features for track 'Miracle' by Julian Perretta in 2016.
# Got high audio features for track 'Miracle' by Julian Perretta in 2016.
# AcousticBrainz error for MBID low-level d2ed4cd6-b8bc-4500-bba6-56518c3c76ef: HTTP 404
# AcousticBrainz error for MBID high-level d2ed4cd6-b8bc-4500-bba6-56518c3c76ef: HTTP 404
# Low audio features not found for track 'My House' by Flo Rida in 2016.
# High audio features not found for track 'My House' by Flo Rida in 2016.
# AcousticBrainz error for MBID low-level f677d457-ac20-4151-b619-c114ffd6bec6: HTTP 404
# AcousticBrainz error for MBID high-level f677d457-ac20-4151-b619-c114ffd6bec6: HTTP 404
# Low audio features not found for track 'Spirits' by The Strumbellas in 2016.
# High audio features not found for track 'Spirits' by The Strumbellas in 2016.
# AcousticBrainz error for MBID low-level 8492fcd6-1ad2-4d09-b801-612f58359805: HTTP 404
# AcousticBrainz error for MBID high-level 8492fcd6-1ad2-4d09-b801-612f58359805: HTTP 404
# Low audio features not found for track 'Speeding Cars' by Walking On Cars in 2016.
# High audio features not found for track 'Speeding Cars' by Walking On Cars in 2016.
# AcousticBrainz error for MBID low-level 8e9d3c19-f2c2-4b41-9488-6a75a2d7d5ee: HTTP 404
# AcousticBrainz error for MBID high-level 8e9d3c19-f2c2-4b41-9488-6a75a2d7d5ee: HTTP 404
# Low audio features not found for track 'Hello' by Adele in 2016.
# High audio features not found for track 'Hello' by Adele in 2016.
# AcousticBrainz error for MBID low-level f78d3199-309d-4e80-b5c3-da0aa44fd925: HTTP 404
# AcousticBrainz error for MBID high-level f78d3199-309d-4e80-b5c3-da0aa44fd925: HTTP 404
# Low audio features not found for track 'Renegades' by X Ambassadors in 2016.
# High audio features not found for track 'Renegades' by X Ambassadors in 2016.
# AcousticBrainz error for MBID low-level 7845be64-1911-4dd0-a934-14c96df56376: HTTP 404
# AcousticBrainz error for MBID high-level 7845be64-1911-4dd0-a934-14c96df56376: HTTP 404
# Low audio features not found for track 'Be The One' by Dua Lipa in 2016.
# High audio features not found for track 'Be The One' by Dua Lipa in 2016.
# AcousticBrainz error for MBID low-level 2b5a82a9-5828-42a6-bbb7-3d6976d1df68: HTTP 404
# AcousticBrainz error for MBID high-level 2b5a82a9-5828-42a6-bbb7-3d6976d1df68: HTTP 404
# Low audio features not found for track 'Ride' by Twenty One Pilots in 2016.
# High audio features not found for track 'Ride' by Twenty One Pilots in 2016.
# Got low audio features for track 'Holland' by 257ers in 2016.
# Got high audio features for track 'Holland' by 257ers in 2016.
# AcousticBrainz error for MBID low-level c0af0680-0700-4e4d-81ff-824835c4bac3: HTTP 404
# AcousticBrainz error for MBID high-level c0af0680-0700-4e4d-81ff-824835c4bac3: HTTP 404
# Low audio features not found for track 'Show Me Love' by Robin Schulz & J.U.D.G.E. in 2016.
# High audio features not found for track 'Show Me Love' by Robin Schulz & J.U.D.G.E. in 2016.
# Got low audio features for track 'Chöre' by Mark Forster in 2016.
# Got high audio features for track 'Chöre' by Mark Forster in 2016.
# AcousticBrainz error for MBID low-level 6298b3c9-0712-416f-a9df-223ce375a287: HTTP 404
# AcousticBrainz error for MBID high-level 6298b3c9-0712-416f-a9df-223ce375a287: HTTP 404
# Low audio features not found for track 'Ich will nur dass du weißt' by SDP feat. Adel Tawil in 2016.
# High audio features not found for track 'Ich will nur dass du weißt' by SDP feat. Adel Tawil in 2016.
# Got low audio features for track 'Never Forget You' by Zara Larsson & MNEK in 2016.
# Got high audio features for track 'Never Forget You' by Zara Larsson & MNEK in 2016.
# AcousticBrainz error for MBID low-level 4e16dd07-0638-47a2-89e2-0628224db5f9: HTTP 404
# AcousticBrainz error for MBID high-level 4e16dd07-0638-47a2-89e2-0628224db5f9: HTTP 404
# Low audio features not found for track 'Say You Won't Let Go' by James Arthur in 2016.
# High audio features not found for track 'Say You Won't Let Go' by James Arthur in 2016.
# AcousticBrainz error for MBID low-level 208b52d6-63cb-410b-9f05-5610e5b8cb63: HTTP 404
# AcousticBrainz error for MBID high-level 208b52d6-63cb-410b-9f05-5610e5b8cb63: HTTP 404
# Low audio features not found for track 'Sofia' by Alvaro Soler in 2016.
# High audio features not found for track 'Sofia' by Alvaro Soler in 2016.
# AcousticBrainz error for MBID low-level 89a429ec-a5a4-451e-9761-2a4ef2bd3b05: HTTP 404
# AcousticBrainz error for MBID high-level 89a429ec-a5a4-451e-9761-2a4ef2bd3b05: HTTP 404
# Low audio features not found for track 'Musik sein' by Wincent Weiss in 2016.
# High audio features not found for track 'Musik sein' by Wincent Weiss in 2016.
# AcousticBrainz error for MBID low-level fae51718-c255-4c91-88f5-9e1ba55888af: HTTP 404
# AcousticBrainz error for MBID high-level fae51718-c255-4c91-88f5-9e1ba55888af: HTTP 404
# Low audio features not found for track 'Sugar' by Robin Schulz feat. Francesco Yates in 2016.
# High audio features not found for track 'Sugar' by Robin Schulz feat. Francesco Yates in 2016.
# AcousticBrainz error for MBID low-level 9daeef38-1532-4542-8fcf-76c2c3ba3bbc: HTTP 404
# AcousticBrainz error for MBID high-level 9daeef38-1532-4542-8fcf-76c2c3ba3bbc: HTTP 404
# Low audio features not found for track 'Howling At The Moon' by Milow in 2016.
# High audio features not found for track 'Howling At The Moon' by Milow in 2016.
# AcousticBrainz error for MBID low-level bd4b6527-27eb-42f1-8525-a560a0ffb752: HTTP 404
# AcousticBrainz error for MBID high-level bd4b6527-27eb-42f1-8525-a560a0ffb752: HTTP 404
# Low audio features not found for track 'Sweet Lovin'' by Sigala feat. Bryn Christopher in 2016.
# High audio features not found for track 'Sweet Lovin'' by Sigala feat. Bryn Christopher in 2016.
# AcousticBrainz error for MBID low-level 9266008e-b82c-4091-a6b1-ae07afecb077: HTTP 404
# AcousticBrainz error for MBID high-level 9266008e-b82c-4091-a6b1-ae07afecb077: HTTP 404
# Low audio features not found for track 'Heatwave' by Robin Schulz feat. Akon in 2016.
# High audio features not found for track 'Heatwave' by Robin Schulz feat. Akon in 2016.
# AcousticBrainz error for MBID low-level dbcc8c42-8291-4853-bbd4-62bf6c0a774f: HTTP 404
# AcousticBrainz error for MBID high-level dbcc8c42-8291-4853-bbd4-62bf6c0a774f: HTTP 404
# Low audio features not found for track 'Roses' by The Chainsmokers feat. Rozes in 2016.
# High audio features not found for track 'Roses' by The Chainsmokers feat. Rozes in 2016.
# AcousticBrainz error for MBID low-level 482ffcd4-026d-4ee1-841c-03b16acb5047: HTTP 404
# AcousticBrainz error for MBID high-level 482ffcd4-026d-4ee1-841c-03b16acb5047: HTTP 404
# Low audio features not found for track 'Kokaina' by Miami Yacine in 2016.
# High audio features not found for track 'Kokaina' by Miami Yacine in 2016.
# AcousticBrainz error for MBID low-level 1904ff80-80ff-492d-b7b0-9ac75a8b9dbf: HTTP 404
# AcousticBrainz error for MBID high-level 1904ff80-80ff-492d-b7b0-9ac75a8b9dbf: HTTP 404
# Low audio features not found for track 'Pillowtalk' by Zayn in 2016.
# High audio features not found for track 'Pillowtalk' by Zayn in 2016.
# AcousticBrainz error for MBID low-level 9184aef3-2db2-404b-9ada-c21dbbe6ee81: HTTP 404
# AcousticBrainz error for MBID high-level 9184aef3-2db2-404b-9ada-c21dbbe6ee81: HTTP 404
# Low audio features not found for track 'Ain't My Fault' by Zara Larsson in 2016.
# High audio features not found for track 'Ain't My Fault' by Zara Larsson in 2016.
# AcousticBrainz error for MBID low-level 67ca9148-7c71-462a-8079-7c972cfef7c0: HTTP 404
# AcousticBrainz error for MBID high-level 67ca9148-7c71-462a-8079-7c972cfef7c0: HTTP 404
# Low audio features not found for track 'Hundred Miles' by Yall feat. Gabriela Richardson in 2016.
# High audio features not found for track 'Hundred Miles' by Yall feat. Gabriela Richardson in 2016.
# Got low audio features for track 'Sex ohne Grund' by Ali Bumaye feat. Shindy in 2016.
# Got high audio features for track 'Sex ohne Grund' by Ali Bumaye feat. Shindy in 2016.
# Got low audio features for track 'No' by Meghan Trainor in 2016.
# Got high audio features for track 'No' by Meghan Trainor in 2016.
# Got low audio features for track 'Mercy' by Shawn Mendes in 2016.
# Got high audio features for track 'Mercy' by Shawn Mendes in 2016.
# Got low audio features for track 'Stoff und Schnaps' by Lil Kleine & Ronnie Flex in 2016.
# Got high audio features for track 'Stoff und Schnaps' by Lil Kleine & Ronnie Flex in 2016.
# No MBID for track 'Capsize' by Frenship + Emily Warren in 2016.
# AcousticBrainz error for MBID low-level f09bc267-0dd0-4fe1-bc9e-1864915ad9fb: HTTP 404
# AcousticBrainz error for MBID high-level f09bc267-0dd0-4fe1-bc9e-1864915ad9fb: HTTP 404
# Low audio features not found for track 'Side To Side' by Ariana Grande feat. Nicki Minaj in 2016.
# High audio features not found for track 'Side To Side' by Ariana Grande feat. Nicki Minaj in 2016.
# Got low audio features for track 'Astronaut' by Sido feat. Andreas Bourani in 2016.
# Got high audio features for track 'Astronaut' by Sido feat. Andreas Bourani in 2016.
# AcousticBrainz error for MBID low-level 704ecdb3-4ee3-488d-b350-b7e8cad45658: HTTP 404
# AcousticBrainz error for MBID high-level 704ecdb3-4ee3-488d-b350-b7e8cad45658: HTTP 404
# Low audio features not found for track 'Mörder' by Bonez MC & RAF Camora feat. Gzuz in 2016.
# High audio features not found for track 'Mörder' by Bonez MC & RAF Camora feat. Gzuz in 2016.
# Got low audio features for track 'Wherever I Go' by OneRepublic in 2016.
# Got high audio features for track 'Wherever I Go' by OneRepublic in 2016.
# AcousticBrainz error for MBID low-level b8111227-037b-4021-a76c-b25eac94bf0c: HTTP 404
# AcousticBrainz error for MBID high-level b8111227-037b-4021-a76c-b25eac94bf0c: HTTP 404
# Low audio features not found for track 'Just Like Fire' by P!nk in 2016.
# High audio features not found for track 'Just Like Fire' by P!nk in 2016.
# Processing year 2017...
# AcousticBrainz error for MBID low-level c664a576-f0e5-4725-8d52-05ecfe4822d8: HTTP 404
# AcousticBrainz error for MBID high-level c664a576-f0e5-4725-8d52-05ecfe4822d8: HTTP 404
# Low audio features not found for track 'Shape Of You' by Ed Sheeran in 2017.
# High audio features not found for track 'Shape Of You' by Ed Sheeran in 2017.
# AcousticBrainz error for MBID low-level 678ce6e5-2bb6-4a5f-8a50-b65a4ccbc044: HTTP 404
# AcousticBrainz error for MBID high-level 678ce6e5-2bb6-4a5f-8a50-b65a4ccbc044: HTTP 404
# Low audio features not found for track 'Despacito' by Luis Fonsi feat. Daddy Yankee in 2017.
# High audio features not found for track 'Despacito' by Luis Fonsi feat. Daddy Yankee in 2017.
# AcousticBrainz error for MBID low-level 77645558-ad88-48a4-b0f8-f4ff7562a77e: HTTP 404
# AcousticBrainz error for MBID high-level 77645558-ad88-48a4-b0f8-f4ff7562a77e: HTTP 404
# Low audio features not found for track 'Something Just Like This' by The Chainsmokers & Coldplay in 2017.
# High audio features not found for track 'Something Just Like This' by The Chainsmokers & Coldplay in 2017.
# AcousticBrainz error for MBID low-level 9503985b-5098-417c-9e50-5d36011a408e: HTTP 404
# AcousticBrainz error for MBID high-level 9503985b-5098-417c-9e50-5d36011a408e: HTTP 404
# Low audio features not found for track 'Thunder' by Imagine Dragons in 2017.
# High audio features not found for track 'Thunder' by Imagine Dragons in 2017.
# Got low audio features for track 'Tuesday' by Burak Yeter feat. Danelle Sandoval in 2017.
# Got high audio features for track 'Tuesday' by Burak Yeter feat. Danelle Sandoval in 2017.
# AcousticBrainz error for MBID low-level 90b98021-6ee4-4140-bfc7-49c0fe8c69c5: HTTP 404
# AcousticBrainz error for MBID high-level 90b98021-6ee4-4140-bfc7-49c0fe8c69c5: HTTP 404
# Low audio features not found for track 'More Than You Know' by Axwell Λ Ingrosso in 2017.
# High audio features not found for track 'More Than You Know' by Axwell Λ Ingrosso in 2017.
# AcousticBrainz error for MBID low-level 63b28fff-c145-4aef-81bd-52d7cac64590: HTTP 404
# AcousticBrainz error for MBID high-level 63b28fff-c145-4aef-81bd-52d7cac64590: HTTP 404
# Low audio features not found for track 'OK' by Robin Schulz feat. James Blunt in 2017.
# High audio features not found for track 'OK' by Robin Schulz feat. James Blunt in 2017.
# Got low audio features for track 'Was du Liebe nennst' by Bausa in 2017.
# Got high audio features for track 'Was du Liebe nennst' by Bausa in 2017.
# AcousticBrainz error for MBID low-level 763b6986-ed14-40a3-94f7-41224260b79c: HTTP 404
# AcousticBrainz error for MBID high-level 763b6986-ed14-40a3-94f7-41224260b79c: HTTP 404
# Low audio features not found for track 'Unforgettable' by French Montana feat. Swae Lee in 2017.
# High audio features not found for track 'Unforgettable' by French Montana feat. Swae Lee in 2017.
# AcousticBrainz error for MBID low-level cef35ef2-fe16-4b79-93ad-9cfff8039cee: HTTP 404
# AcousticBrainz error for MBID high-level cef35ef2-fe16-4b79-93ad-9cfff8039cee: HTTP 404
# Low audio features not found for track 'Galway Girl' by Ed Sheeran in 2017.
# High audio features not found for track 'Galway Girl' by Ed Sheeran in 2017.
# AcousticBrainz error for MBID low-level eacb3f24-f080-4ed7-bd04-f673ec8e2ebc: HTTP 404
# AcousticBrainz error for MBID high-level eacb3f24-f080-4ed7-bd04-f673ec8e2ebc: HTTP 404
# Low audio features not found for track 'Swalla' by Jason Derulo feat. Nicki Minaj & Ty Dolla $ign in 2017.
# High audio features not found for track 'Swalla' by Jason Derulo feat. Nicki Minaj & Ty Dolla $ign in 2017.
# AcousticBrainz error for MBID low-level 2a0e6123-9673-47f8-acf8-de20c5e7265b: HTTP 404
# AcousticBrainz error for MBID high-level 2a0e6123-9673-47f8-acf8-de20c5e7265b: HTTP 404
# Low audio features not found for track 'Perfect' by Ed Sheeran in 2017.
# High audio features not found for track 'Perfect' by Ed Sheeran in 2017.
# AcousticBrainz error for MBID low-level b68393a7-e9b0-427d-92f7-76b923910eba: HTTP 404
# AcousticBrainz error for MBID high-level b68393a7-e9b0-427d-92f7-76b923910eba: HTTP 404
# Low audio features not found for track 'It Ain't Me' by Kygo & Selena Gomez in 2017.
# High audio features not found for track 'It Ain't Me' by Kygo & Selena Gomez in 2017.
# AcousticBrainz error for MBID low-level 3204b83f-9f19-4f17-a09b-46b04ec0904c: HTTP 404
# AcousticBrainz error for MBID high-level 3204b83f-9f19-4f17-a09b-46b04ec0904c: HTTP 404
# Low audio features not found for track 'No Roots' by Alice Merton in 2017.
# High audio features not found for track 'No Roots' by Alice Merton in 2017.
# AcousticBrainz error for MBID low-level 9ebf03c0-710b-4eeb-bbe7-6d6d0e2e9747: HTTP 404
# AcousticBrainz error for MBID high-level 9ebf03c0-710b-4eeb-bbe7-6d6d0e2e9747: HTTP 404
# Low audio features not found for track 'Mi gente' by J Balvin & Willy William in 2017.
# High audio features not found for track 'Mi gente' by J Balvin & Willy William in 2017.
# AcousticBrainz error for MBID low-level cb09a609-011b-43e8-a1b5-247b1926d26a: HTTP 404
# AcousticBrainz error for MBID high-level cb09a609-011b-43e8-a1b5-247b1926d26a: HTTP 404
# Low audio features not found for track 'Mama' by Jonas Blue feat. William Singe in 2017.
# High audio features not found for track 'Mama' by Jonas Blue feat. William Singe in 2017.
# AcousticBrainz error for MBID low-level dba8ab92-1d66-4ba7-9462-5465b0926745: HTTP 404
# AcousticBrainz error for MBID high-level dba8ab92-1d66-4ba7-9462-5465b0926745: HTTP 404
# Low audio features not found for track 'Ohne mein Team' by Bonez MC & RAF Camora feat. Maxwell in 2017.
# High audio features not found for track 'Ohne mein Team' by Bonez MC & RAF Camora feat. Maxwell in 2017.
# AcousticBrainz error for MBID low-level 0f4eda4e-6c6c-427e-8728-c48d8f26921c: HTTP 404
# AcousticBrainz error for MBID high-level 0f4eda4e-6c6c-427e-8728-c48d8f26921c: HTTP 404
# Low audio features not found for track 'Havana' by Camila Cabello feat. Young Thug in 2017.
# High audio features not found for track 'Havana' by Camila Cabello feat. Young Thug in 2017.
# Got low audio features for track 'There's Nothing Holdin' Me Back' by Shawn Mendes in 2017.
# Got high audio features for track 'There's Nothing Holdin' Me Back' by Shawn Mendes in 2017.
# AcousticBrainz error for MBID low-level 471aa043-dd5e-410d-84e0-abfebc321614: HTTP 404
# AcousticBrainz error for MBID high-level 471aa043-dd5e-410d-84e0-abfebc321614: HTTP 404
# Low audio features not found for track 'You Don't Know Me' by Jax Jones feat. Raye in 2017.
# High audio features not found for track 'You Don't Know Me' by Jax Jones feat. Raye in 2017.
# AcousticBrainz error for MBID low-level 474a0cf5-81cf-41e3-aaca-50cc189db6de: HTTP 404
# AcousticBrainz error for MBID high-level 474a0cf5-81cf-41e3-aaca-50cc189db6de: HTTP 404
# Low audio features not found for track 'Rockstar' by Post Malone feat. 21 Savage in 2017.
# High audio features not found for track 'Rockstar' by Post Malone feat. 21 Savage in 2017.
# AcousticBrainz error for MBID low-level 318d12f7-4e91-4583-936a-3693041fe5dc: HTTP 404
# AcousticBrainz error for MBID high-level 318d12f7-4e91-4583-936a-3693041fe5dc: HTTP 404
# Low audio features not found for track 'Attention' by Charlie Puth in 2017.
# High audio features not found for track 'Attention' by Charlie Puth in 2017.
# AcousticBrainz error for MBID low-level 790ecbb2-2944-4f29-805c-ee84a73d5018: HTTP 404
# AcousticBrainz error for MBID high-level 790ecbb2-2944-4f29-805c-ee84a73d5018: HTTP 404
# Low audio features not found for track 'Castle On The Hill' by Ed Sheeran in 2017.
# High audio features not found for track 'Castle On The Hill' by Ed Sheeran in 2017.
# Got low audio features for track 'Dusk Till Dawn' by Zayn feat. Sia in 2017.
# Got high audio features for track 'Dusk Till Dawn' by Zayn feat. Sia in 2017.
# AcousticBrainz error for MBID low-level 70585ded-fedc-4b44-8141-bcdd9171fb95: HTTP 404
# AcousticBrainz error for MBID high-level 70585ded-fedc-4b44-8141-bcdd9171fb95: HTTP 404
# Low audio features not found for track 'Señorita' by Kay One feat. Pietro Lombardi in 2017.
# High audio features not found for track 'Señorita' by Kay One feat. Pietro Lombardi in 2017.
# AcousticBrainz error for MBID low-level b5c3f1b0-24b6-4d27-8395-c15f9769b342: HTTP 404
# AcousticBrainz error for MBID high-level b5c3f1b0-24b6-4d27-8395-c15f9769b342: HTTP 404
# Low audio features not found for track 'Be Mine' by Ofenbach in 2017.
# High audio features not found for track 'Be Mine' by Ofenbach in 2017.
# AcousticBrainz error for MBID low-level e0672206-d5b8-45d4-b114-513ecf29a4e2: HTTP 404
# AcousticBrainz error for MBID high-level e0672206-d5b8-45d4-b114-513ecf29a4e2: HTTP 404
# Low audio features not found for track 'Your Song' by Rita Ora in 2017.
# High audio features not found for track 'Your Song' by Rita Ora in 2017.
# Got low audio features for track 'Wild Thoughts' by DJ Khaled feat. Rihanna & Bryson Tiller in 2017.
# Got high audio features for track 'Wild Thoughts' by DJ Khaled feat. Rihanna & Bryson Tiller in 2017.
# Got low audio features for track 'Rockabye' by Clean Bandit feat. Sean Paul & Anne-Marie in 2017.
# Got high audio features for track 'Rockabye' by Clean Bandit feat. Sean Paul & Anne-Marie in 2017.
# AcousticBrainz error for MBID low-level dba7d3ea-d333-4f6d-8800-a16e686802fd: HTTP 404
# AcousticBrainz error for MBID high-level dba7d3ea-d333-4f6d-8800-a16e686802fd: HTTP 404
# Low audio features not found for track 'Strip That Down' by Liam Payne feat. Quavo in 2017.
# High audio features not found for track 'Strip That Down' by Liam Payne feat. Quavo in 2017.
# Got low audio features for track 'Heute mit mir' by Nimo in 2017.
# Got high audio features for track 'Heute mit mir' by Nimo in 2017.
# No MBID for track 'I Don't Wanna Live Forever (Fifty Shades Darker)' by Zayn & Taylor Swift in 2017.
# Got low audio features for track 'Súbeme la radio' by Enrique Iglesias feat. Descemer Bueno, Zion & Lennox in 2017.
# Got high audio features for track 'Súbeme la radio' by Enrique Iglesias feat. Descemer Bueno, Zion & Lennox in 2017.
# AcousticBrainz error for MBID low-level 6a9268d0-8051-40ec-96df-742107b3360e: HTTP 404
# AcousticBrainz error for MBID high-level 6a9268d0-8051-40ec-96df-742107b3360e: HTTP 404
# Low audio features not found for track 'Symphony' by Clean Bandit feat. Zara Larsson in 2017.
# High audio features not found for track 'Symphony' by Clean Bandit feat. Zara Larsson in 2017.
# AcousticBrainz error for MBID low-level 3f48bd8a-1c07-40d0-8c6d-ec0429cba3c8: HTTP 404
# AcousticBrainz error for MBID high-level 3f48bd8a-1c07-40d0-8c6d-ec0429cba3c8: HTTP 404
# Low audio features not found for track 'Friends' by Justin Bieber + BloodPop® in 2017.
# High audio features not found for track 'Friends' by Justin Bieber + BloodPop® in 2017.
# AcousticBrainz error for MBID low-level 473b54aa-cb52-420e-b1a0-c24227a76b07: HTTP 404
# AcousticBrainz error for MBID high-level 473b54aa-cb52-420e-b1a0-c24227a76b07: HTTP 404
# Low audio features not found for track 'Wohin willst du' by Gestört aber GeiL feat. Lea in 2017.
# High audio features not found for track 'Wohin willst du' by Gestört aber GeiL feat. Lea in 2017.
# AcousticBrainz error for MBID low-level f3645b47-224b-4190-8c24-2741aab235cb: HTTP 404
# AcousticBrainz error for MBID high-level f3645b47-224b-4190-8c24-2741aab235cb: HTTP 404
# Low audio features not found for track 'Believer' by Imagine Dragons in 2017.
# High audio features not found for track 'Believer' by Imagine Dragons in 2017.
# AcousticBrainz error for MBID low-level 7ea6bb55-f990-456f-be4a-67520f41f649: HTTP 404
# AcousticBrainz error for MBID high-level 7ea6bb55-f990-456f-be4a-67520f41f649: HTTP 404
# Low audio features not found for track 'Paris' by The Chainsmokers in 2017.
# High audio features not found for track 'Paris' by The Chainsmokers in 2017.
# AcousticBrainz error for MBID low-level 1cf3457e-f56c-4e4b-a372-3eee640d5cbb: HTTP 404
# AcousticBrainz error for MBID high-level 1cf3457e-f56c-4e4b-a372-3eee640d5cbb: HTTP 404
# Low audio features not found for track 'What About Us' by P!nk in 2017.
# High audio features not found for track 'What About Us' by P!nk in 2017.
# AcousticBrainz error for MBID low-level 474abc30-a329-4af0-abbd-9e0df493339c: HTTP 404
# AcousticBrainz error for MBID high-level 474abc30-a329-4af0-abbd-9e0df493339c: HTTP 404
# Low audio features not found for track 'I'm The One' by DJ Khaled feat. Justin Bieber, Quavo, Chance The Rapper & Lil Wayne in 2017.
# High audio features not found for track 'I'm The One' by DJ Khaled feat. Justin Bieber, Quavo, Chance The Rapper & Lil Wayne in 2017.
# AcousticBrainz error for MBID low-level 39b386c9-a9fd-44ca-a085-543abce812a6: HTTP 404
# AcousticBrainz error for MBID high-level 39b386c9-a9fd-44ca-a085-543abce812a6: HTTP 404
# Low audio features not found for track 'New Rules' by Dua Lipa in 2017.
# High audio features not found for track 'New Rules' by Dua Lipa in 2017.
# AcousticBrainz error for MBID low-level a5ddb256-b662-4df0-8b39-7cac2f44e462: HTTP 404
# AcousticBrainz error for MBID high-level a5ddb256-b662-4df0-8b39-7cac2f44e462: HTTP 404
# Low audio features not found for track 'I Like Me Better' by Lauv in 2017.
# High audio features not found for track 'I Like Me Better' by Lauv in 2017.
# AcousticBrainz error for MBID low-level 8c36762f-41a5-43bd-bcf6-5189ceb55ad7: HTTP 404
# AcousticBrainz error for MBID high-level 8c36762f-41a5-43bd-bcf6-5189ceb55ad7: HTTP 404
# Low audio features not found for track 'Hot2Touch' by Felix Jaehn, Hight & Alex Aiono in 2017.
# High audio features not found for track 'Hot2Touch' by Felix Jaehn, Hight & Alex Aiono in 2017.
# AcousticBrainz error for MBID low-level 4af0f34c-c22b-4e04-99fb-e49fd397c848: HTTP 404
# AcousticBrainz error for MBID high-level 4af0f34c-c22b-4e04-99fb-e49fd397c848: HTTP 404
# Low audio features not found for track 'Call On Me' by Starley in 2017.
# High audio features not found for track 'Call On Me' by Starley in 2017.
# Got low audio features for track 'Silence' by Marshmello feat. Khalid in 2017.
# Got high audio features for track 'Silence' by Marshmello feat. Khalid in 2017.
# AcousticBrainz error for MBID low-level 1c9614e7-f0a8-4b84-8e85-a3f6f7640f25: HTTP 404
# AcousticBrainz error for MBID high-level 1c9614e7-f0a8-4b84-8e85-a3f6f7640f25: HTTP 404
# Low audio features not found for track '2U' by David Guetta feat. Justin Bieber in 2017.
# High audio features not found for track '2U' by David Guetta feat. Justin Bieber in 2017.
# AcousticBrainz error for MBID low-level a26d400d-cd71-45f5-9f74-23d41d9fd3ac: HTTP 404
# AcousticBrainz error for MBID high-level a26d400d-cd71-45f5-9f74-23d41d9fd3ac: HTTP 404
# Low audio features not found for track 'Solo Dance' by Martin Jensen in 2017.
# High audio features not found for track 'Solo Dance' by Martin Jensen in 2017.
# Got low audio features for track 'Sowieso' by Mark Forster in 2017.
# Got high audio features for track 'Sowieso' by Mark Forster in 2017.
# Got low audio features for track 'Bon voyage' by Miami Yacine in 2017.
# Got high audio features for track 'Bon voyage' by Miami Yacine in 2017.
# Got low audio features for track 'Unendlichkeit' by Cro in 2017.
# Got high audio features for track 'Unendlichkeit' by Cro in 2017.
# Got low audio features for track 'Little Hollywood' by Alle Farben & Janieck in 2017.
# Got high audio features for track 'Little Hollywood' by Alle Farben & Janieck in 2017.
# AcousticBrainz error for MBID low-level 27cbb272-0e12-4677-8c62-01ae9d00757f: HTTP 404
# AcousticBrainz error for MBID high-level 27cbb272-0e12-4677-8c62-01ae9d00757f: HTTP 404
# Low audio features not found for track 'Scared To Be Lonely' by Martin Garrix & Dua Lipa in 2017.
# High audio features not found for track 'Scared To Be Lonely' by Martin Garrix & Dua Lipa in 2017.
# AcousticBrainz error for MBID low-level 7f205890-07f3-487c-bef1-e7d251dc867b: HTTP 404
# AcousticBrainz error for MBID high-level 7f205890-07f3-487c-bef1-e7d251dc867b: HTTP 404
# Low audio features not found for track 'Mask Off' by Future in 2017.
# High audio features not found for track 'Mask Off' by Future in 2017.
# AcousticBrainz error for MBID low-level b26e5a13-ff28-41db-8c8d-1eeb09a5f879: HTTP 404
# AcousticBrainz error for MBID high-level b26e5a13-ff28-41db-8c8d-1eeb09a5f879: HTTP 404
# Low audio features not found for track 'Loin' by Maître Gims feat. Dany Synthé in 2017.
# High audio features not found for track 'Loin' by Maître Gims feat. Dany Synthé in 2017.
# Got low audio features for track 'Ist da jemand' by Adel Tawil in 2017.
# Got high audio features for track 'Ist da jemand' by Adel Tawil in 2017.
# AcousticBrainz error for MBID low-level b5a11f7c-9ec7-4b1d-b681-697cb2df5322: HTTP 404
# AcousticBrainz error for MBID high-level b5a11f7c-9ec7-4b1d-b681-697cb2df5322: HTTP 404
# Low audio features not found for track 'Skin' by Rag'n'Bone Man in 2017.
# High audio features not found for track 'Skin' by Rag'n'Bone Man in 2017.
# Got low audio features for track 'Stay' by Zedd & Alessia Cara in 2017.
# Got high audio features for track 'Stay' by Zedd & Alessia Cara in 2017.
# No MBID for track 'Nummer 1' by Zuna feat. Azet & Noizy in 2017.
# AcousticBrainz error for MBID low-level dc0c8aaa-5772-427b-89b1-acc9bd17e4b9: HTTP 404
# AcousticBrainz error for MBID high-level dc0c8aaa-5772-427b-89b1-acc9bd17e4b9: HTTP 404
# Low audio features not found for track 'Feels' by Calvin Harris feat. Pharrell Williams, Katy Perry & Big Sean in 2017.
# High audio features not found for track 'Feels' by Calvin Harris feat. Pharrell Williams, Katy Perry & Big Sean in 2017.
# AcousticBrainz error for MBID low-level 1e09e7ae-97c2-48f9-9748-224d0ebb4a89: HTTP 404
# AcousticBrainz error for MBID high-level 1e09e7ae-97c2-48f9-9748-224d0ebb4a89: HTTP 404
# Low audio features not found for track 'Herzbeben' by Helene Fischer in 2017.
# High audio features not found for track 'Herzbeben' by Helene Fischer in 2017.
# AcousticBrainz error for MBID low-level 6403a189-8382-4f75-b693-d6a52b82b81d: HTTP 404
# AcousticBrainz error for MBID high-level 6403a189-8382-4f75-b693-d6a52b82b81d: HTTP 404
# Low audio features not found for track 'Way Down We Go' by Kaleo in 2017.
# High audio features not found for track 'Way Down We Go' by Kaleo in 2017.
# AcousticBrainz error for MBID low-level e63ffb76-2686-4fad-9016-3069681fa916: HTTP 404
# AcousticBrainz error for MBID high-level e63ffb76-2686-4fad-9016-3069681fa916: HTTP 404
# Low audio features not found for track 'Alone' by Alan Walker in 2017.
# High audio features not found for track 'Alone' by Alan Walker in 2017.
# Got low audio features for track 'Chöre' by Mark Forster in 2017.
# Got high audio features for track 'Chöre' by Mark Forster in 2017.
# AcousticBrainz error for MBID low-level 20d81d37-fc4f-4e7b-baf3-626ba2079792: HTTP 404
# AcousticBrainz error for MBID high-level 20d81d37-fc4f-4e7b-baf3-626ba2079792: HTTP 404
# Low audio features not found for track 'Chained To The Rhythm' by Katy Perry feat. Skip Marley in 2017.
# High audio features not found for track 'Chained To The Rhythm' by Katy Perry feat. Skip Marley in 2017.
# AcousticBrainz error for MBID low-level 74073b96-dd64-4fa8-9510-c00a99809a5b: HTTP 404
# AcousticBrainz error for MBID high-level 74073b96-dd64-4fa8-9510-c00a99809a5b: HTTP 404
# Low audio features not found for track 'Primo' by RAF Camora in 2017.
# High audio features not found for track 'Primo' by RAF Camora in 2017.
# AcousticBrainz error for MBID low-level 903ab349-d31f-4142-99c0-85d3937871c0: HTTP 404
# AcousticBrainz error for MBID high-level 903ab349-d31f-4142-99c0-85d3937871c0: HTTP 404
# Low audio features not found for track 'Legendary' by Welshly Arms in 2017.
# High audio features not found for track 'Legendary' by Welshly Arms in 2017.
# AcousticBrainz error for MBID low-level 12838ff3-446d-4e25-976f-b956d2c1690f: HTTP 404
# ...
# Low audio features not found for track 'Unholy' by Sam Smith & Kim Petras in 2022.
# High audio features not found for track 'Unholy' by Sam Smith & Kim Petras in 2022.
# AcousticBrainz error for MBID low-level a2c09319-d701-4c93-ab02-9835191df46d: HTTP 404
# AcousticBrainz error for MBID high-level a2c09319-d701-4c93-ab02-9835191df46d: HTTP 404
# Low audio features not found for track '10von10' by Pajel in 2022.
# High audio features not found for track '10von10' by Pajel in 2022.
# No MBID for track 'In The Dark' by Purple Disco Machine + Sophie And The Giants in 2022.
# AcousticBrainz error for MBID low-level 4634f016-fe1c-42db-b732-8acbbc0d113b: HTTP 404
# AcousticBrainz error for MBID high-level 4634f016-fe1c-42db-b732-8acbbc0d113b: HTTP 404
# Low audio features not found for track 'Down Under' by Luude feat. Colin Hay in 2022.
# High audio features not found for track 'Down Under' by Luude feat. Colin Hay in 2022.
# AcousticBrainz error for MBID low-level d796a70d-65c6-4ee8-bec7-1a3979c6cb78: HTTP 404
# AcousticBrainz error for MBID high-level d796a70d-65c6-4ee8-bec7-1a3979c6cb78: HTTP 404
# Low audio features not found for track 'Thats What I Want' by Lil Nas X in 2022.
# High audio features not found for track 'Thats What I Want' by Lil Nas X in 2022.
# AcousticBrainz error for MBID low-level c2dd0106-d6e6-4a8d-8f41-a1336fdf3f85: HTTP 404
# AcousticBrainz error for MBID high-level c2dd0106-d6e6-4a8d-8f41-a1336fdf3f85: HTTP 404
# Low audio features not found for track 'Miss You' by Southstar in 2022.
# High audio features not found for track 'Miss You' by Southstar in 2022.
# AcousticBrainz error for MBID low-level ffc56d4a-7306-41df-8431-c2fb094f180b: HTTP 404
# AcousticBrainz error for MBID high-level ffc56d4a-7306-41df-8431-c2fb094f180b: HTTP 404
# Low audio features not found for track 'First Class' by Jack Harlow in 2022.
# High audio features not found for track 'First Class' by Jack Harlow in 2022.
# Got low audio features for track 'Middle Of The Night' by Elley Duhé in 2022.
# Got high audio features for track 'Middle Of The Night' by Elley Duhé in 2022.
# AcousticBrainz error for MBID low-level 1e39f660-b464-4743-b775-f9cbbb95e2b7: HTTP 404
# AcousticBrainz error for MBID high-level 1e39f660-b464-4743-b775-f9cbbb95e2b7: HTTP 404
# Low audio features not found for track 'Save Your Tears' by The Weeknd in 2022.
# High audio features not found for track 'Save Your Tears' by The Weeknd in 2022.
# No MBID for track 'Manila' by Alvaro Soler / Ray Dalton in 2022.
# AcousticBrainz error for MBID low-level d9120513-31f7-4733-b17e-e46813e9f5e6: HTTP 404
# AcousticBrainz error for MBID high-level d9120513-31f7-4733-b17e-e46813e9f5e6: HTTP 404
# Low audio features not found for track 'Zukunft Pink' by Peter Fox feat. Inéz in 2022.
# High audio features not found for track 'Zukunft Pink' by Peter Fox feat. Inéz in 2022.
# AcousticBrainz error for MBID low-level 6a9b8815-76ec-4481-9081-4192a69831bd: HTTP 404
# AcousticBrainz error for MBID high-level 6a9b8815-76ec-4481-9081-4192a69831bd: HTTP 404
# Low audio features not found for track 'Sommergewitter' by Pashanim in 2022.
# High audio features not found for track 'Sommergewitter' by Pashanim in 2022.
# No MBID for track 'Blaues Licht' by RAF Camora feat. Bonez MC in 2022.
# AcousticBrainz error for MBID low-level fceba82a-1400-42e4-a057-2515f481515f: HTTP 404
# AcousticBrainz error for MBID high-level fceba82a-1400-42e4-a057-2515f481515f: HTTP 404
# Low audio features not found for track 'Kopf aus' by 1986zig in 2022.
# High audio features not found for track 'Kopf aus' by 1986zig in 2022.
# No MBID for track 'Brooklyn' by Glockenbach x ClockClock in 2022.
# AcousticBrainz error for MBID low-level eff0d22b-fe0c-45ea-88a7-1295f56d76f5: HTTP 404
# AcousticBrainz error for MBID high-level eff0d22b-fe0c-45ea-88a7-1295f56d76f5: HTTP 404
# Low audio features not found for track 'I Ain't Worried' by OneRepublic in 2022.
# High audio features not found for track 'I Ain't Worried' by OneRepublic in 2022.
# AcousticBrainz error for MBID low-level dafde5f2-d4c4-4eb3-a9b4-172056445723: HTTP 404
# AcousticBrainz error for MBID high-level dafde5f2-d4c4-4eb3-a9b4-172056445723: HTTP 404
# Low audio features not found for track 'Die schönsten Tage' by SDP feat. Clueso in 2022.
# High audio features not found for track 'Die schönsten Tage' by SDP feat. Clueso in 2022.
# AcousticBrainz error for MBID low-level 5bdbfe86-4ad5-4c19-8d29-ee5f30ba628b: HTTP 404
# AcousticBrainz error for MBID high-level 5bdbfe86-4ad5-4c19-8d29-ee5f30ba628b: HTTP 404
# Low audio features not found for track 'Blinding Lights' by The Weeknd in 2022.
# High audio features not found for track 'Blinding Lights' by The Weeknd in 2022.
# AcousticBrainz error for MBID low-level a59a6a5b-25fc-45b0-bd6f-c1bc91ea4c7c: HTTP 404
# AcousticBrainz error for MBID high-level a59a6a5b-25fc-45b0-bd6f-c1bc91ea4c7c: HTTP 404
# Low audio features not found for track 'Olivia' by Die Zipfelbuben feat. DJ Cashi in 2022.
# High audio features not found for track 'Olivia' by Die Zipfelbuben feat. DJ Cashi in 2022.
# Got low audio features for track 'Industry Baby' by Lil Nas X & Jack Harlow in 2022.
# Got high audio features for track 'Industry Baby' by Lil Nas X & Jack Harlow in 2022.
# AcousticBrainz error for MBID low-level e86392c3-7f16-4b57-8e37-628d7e14756f: HTTP 404
# AcousticBrainz error for MBID high-level e86392c3-7f16-4b57-8e37-628d7e14756f: HTTP 404
# Low audio features not found for track 'Under The Influence' by Chris Brown in 2022.
# High audio features not found for track 'Under The Influence' by Chris Brown in 2022.
# Got low audio features for track 'Roller' by Apache 207 in 2022.
# Got high audio features for track 'Roller' by Apache 207 in 2022.
# AcousticBrainz error for MBID low-level f4053f4c-c710-414d-8b7d-434dcb304e02: HTTP 404
# AcousticBrainz error for MBID high-level f4053f4c-c710-414d-8b7d-434dcb304e02: HTTP 404
# Low audio features not found for track 'Good 4 U' by Olivia Rodrigo in 2022.
# High audio features not found for track 'Good 4 U' by Olivia Rodrigo in 2022.
# No MBID for track '61 Grad' by Endzone / TM in 2022.
# AcousticBrainz error for MBID low-level b5d2067d-3671-4625-ac22-eb2e4fb56f62: HTTP 404
# AcousticBrainz error for MBID high-level b5d2067d-3671-4625-ac22-eb2e4fb56f62: HTTP 404
# Low audio features not found for track 'Where Did You Go?' by Jax Jones feat. MNEK in 2022.
# High audio features not found for track 'Where Did You Go?' by Jax Jones feat. MNEK in 2022.
# AcousticBrainz error for MBID low-level b57397b9-6339-41ac-b3cb-1c139cea3144: HTTP 404
# AcousticBrainz error for MBID high-level b57397b9-6339-41ac-b3cb-1c139cea3144: HTTP 404
# Low audio features not found for track 'Young Right Now' by Robin Schulz & Dennis Lloyd in 2022.
# High audio features not found for track 'Young Right Now' by Robin Schulz & Dennis Lloyd in 2022.
# AcousticBrainz error for MBID low-level 3504e326-0672-407f-83ed-592219d5be18: HTTP 404
# AcousticBrainz error for MBID high-level 3504e326-0672-407f-83ed-592219d5be18: HTTP 404
# Low audio features not found for track 'Ausmacht' by Emilio in 2022.
# High audio features not found for track 'Ausmacht' by Emilio in 2022.
# AcousticBrainz error for MBID low-level 67a7271f-d837-4686-ab4c-e8c859f12f93: HTTP 404
# AcousticBrainz error for MBID high-level 67a7271f-d837-4686-ab4c-e8c859f12f93: HTTP 404
# Low audio features not found for track 'Crazy What Love Can Do' by David Guetta, Becky Hill & Ella Henderson in 2022.
# High audio features not found for track 'Crazy What Love Can Do' by David Guetta, Becky Hill & Ella Henderson in 2022.
# Got low audio features for track 'All I Want For Christmas Is You' by Mariah Carey in 2022.
# Got high audio features for track 'All I Want For Christmas Is You' by Mariah Carey in 2022.
# AcousticBrainz error for MBID low-level 327f17da-5416-4ba6-90a4-ff4e4cf068c7: HTTP 404
# AcousticBrainz error for MBID high-level 327f17da-5416-4ba6-90a4-ff4e4cf068c7: HTTP 404
# Low audio features not found for track 'Easy On Me' by Adele in 2022.
# High audio features not found for track 'Easy On Me' by Adele in 2022.
# AcousticBrainz error for MBID low-level 9055b00a-82f9-4997-a51b-b4981c04a9ce: HTTP 404
# AcousticBrainz error for MBID high-level 9055b00a-82f9-4997-a51b-b4981c04a9ce: HTTP 404
# Low audio features not found for track 'Sorry' by ClockClock in 2022.
# High audio features not found for track 'Sorry' by ClockClock in 2022.
# AcousticBrainz error for MBID low-level 65d2e887-8bc2-4d9d-b391-44c40693d982: HTTP 404
# AcousticBrainz error for MBID high-level 65d2e887-8bc2-4d9d-b391-44c40693d982: HTTP 404
# Low audio features not found for track 'Je m'appelle' by Benzz in 2022.
# High audio features not found for track 'Je m'appelle' by Benzz in 2022.
# AcousticBrainz error for MBID low-level b92c457a-fd20-4212-aeab-709c856417c9: HTTP 404
# AcousticBrainz error for MBID high-level b92c457a-fd20-4212-aeab-709c856417c9: HTTP 404
# Low audio features not found for track 'Last Christmas' by Wham! in 2022.
# High audio features not found for track 'Last Christmas' by Wham! in 2022.
# AcousticBrainz error for MBID low-level 366d3cbd-1ecb-4b95-9a0f-2e8ff4f5a461: HTTP 404
# AcousticBrainz error for MBID high-level 366d3cbd-1ecb-4b95-9a0f-2e8ff4f5a461: HTTP 404
# Low audio features not found for track 'Because You Move Me' by Tinlicker & Helsloot in 2022.
# High audio features not found for track 'Because You Move Me' by Tinlicker & Helsloot in 2022.
# No MBID for track 'Kernkraft 400 (A Better Day)' by Topic x A7S in 2022.
# Got low audio features for track 'House Of Memories' by Panic! At The Disco in 2022.
# Got high audio features for track 'House Of Memories' by Panic! At The Disco in 2022.
# AcousticBrainz error for MBID low-level d4a98fd3-9dba-45af-b777-24c5a7d8535c: HTTP 404
# AcousticBrainz error for MBID high-level d4a98fd3-9dba-45af-b777-24c5a7d8535c: HTTP 404
# Low audio features not found for track 'Friday (Dopamine Re-Edit)' by Riton x Nightcrawlers feat. Mufasa & Hypeman in 2022.
# High audio features not found for track 'Friday (Dopamine Re-Edit)' by Riton x Nightcrawlers feat. Mufasa & Hypeman in 2022.
# AcousticBrainz error for MBID low-level 24160618-88b4-4393-bafd-db1e1a4d6a86: HTTP 404
# AcousticBrainz error for MBID high-level 24160618-88b4-4393-bafd-db1e1a4d6a86: HTTP 404
# Low audio features not found for track 'Späti' by Gzuz in 2022.
# High audio features not found for track 'Späti' by Gzuz in 2022.
# AcousticBrainz error for MBID low-level ea289123-e762-4aba-b4d2-df2f96291e89: HTTP 404
# AcousticBrainz error for MBID high-level ea289123-e762-4aba-b4d2-df2f96291e89: HTTP 404
# Low audio features not found for track 'Sunroof' by Nicky Youre & Dazy in 2022.
# High audio features not found for track 'Sunroof' by Nicky Youre & Dazy in 2022.
# Got low audio features for track 'Can't Hold Us' by Macklemore & Ryan Lewis feat. Ray Dalton in 2022.
# Got high audio features for track 'Can't Hold Us' by Macklemore & Ryan Lewis feat. Ray Dalton in 2022.
# Got low audio features for track 'When You're Gone' by Shawn Mendes in 2022.
# Got high audio features for track 'When You're Gone' by Shawn Mendes in 2022.
# Got low audio features for track 'Zick zack' by Rammstein in 2022.
# Got high audio features for track 'Zick zack' by Rammstein in 2022.
# Got low audio features for track 'Zeit' by Rammstein in 2022.
# Got high audio features for track 'Zeit' by Rammstein in 2022.
# Got low audio features for track 'My Universe' by Coldplay x BTS in 2022.
# Got high audio features for track 'My Universe' by Coldplay x BTS in 2022.
# AcousticBrainz error for MBID low-level b197fdfe-f9c9-4b27-bb35-9e832295fcbc: HTTP 404
# AcousticBrainz error for MBID high-level b197fdfe-f9c9-4b27-bb35-9e832295fcbc: HTTP 404
# Low audio features not found for track 'She's All I Wanna Be' by Tate McRae in 2022.
# High audio features not found for track 'She's All I Wanna Be' by Tate McRae in 2022.
# AcousticBrainz error for MBID low-level b29f7795-3010-4a7d-abbe-254537b01191: HTTP 404
# AcousticBrainz error for MBID high-level b29f7795-3010-4a7d-abbe-254537b01191: HTTP 404
# Low audio features not found for track 'Doja' by Central Cee in 2022.
# High audio features not found for track 'Doja' by Central Cee in 2022.
# AcousticBrainz error for MBID low-level 598d2e86-938c-4e16-ba7f-75c8d41f67bc: HTTP 404
# AcousticBrainz error for MBID high-level 598d2e86-938c-4e16-ba7f-75c8d41f67bc: HTTP 404
# Low audio features not found for track 'Love Nwantiti (North African Remix)' by CKay feat. ElGrande Toto in 2022.
# High audio features not found for track 'Love Nwantiti (North African Remix)' by CKay feat. ElGrande Toto in 2022.
# AcousticBrainz error for MBID low-level e7d4a352-cf63-4c6d-8721-409ca57db03d: HTTP 404
# AcousticBrainz error for MBID high-level e7d4a352-cf63-4c6d-8721-409ca57db03d: HTTP 404
# Low audio features not found for track 'Calm Down' by Rema in 2022.
# High audio features not found for track 'Calm Down' by Rema in 2022.
# AcousticBrainz error for MBID low-level 6c2280a2-0dab-4f06-aca2-8e4320a3b874: HTTP 404
# AcousticBrainz error for MBID high-level 6c2280a2-0dab-4f06-aca2-8e4320a3b874: HTTP 404
# Low audio features not found for track 'Friendships (Lost My Love)' by Pascal Letoublon feat. Leony in 2022.
# High audio features not found for track 'Friendships (Lost My Love)' by Pascal Letoublon feat. Leony in 2022.
# AcousticBrainz error for MBID low-level 9c847aa6-15bf-48b3-8d82-aabd06aabec5: HTTP 404
# AcousticBrainz error for MBID high-level 9c847aa6-15bf-48b3-8d82-aabd06aabec5: HTTP 404
# Low audio features not found for track 'Paris Freestyle' by Pashanim in 2022.
# High audio features not found for track 'Paris Freestyle' by Pashanim in 2022.
# AcousticBrainz error for MBID low-level bce1d543-acae-41e6-a935-a5dddfb01188: HTTP 404
# AcousticBrainz error for MBID high-level bce1d543-acae-41e6-a935-a5dddfb01188: HTTP 404
# Low audio features not found for track 'Rain In Ibiza' by Felix Jaehn & The Stickmen Project feat. Calum Scott in 2022.
# High audio features not found for track 'Rain In Ibiza' by Felix Jaehn & The Stickmen Project feat. Calum Scott in 2022.
# AcousticBrainz error for MBID low-level d211ee00-5543-4add-8f3a-79b1dc097866: HTTP 404
# AcousticBrainz error for MBID high-level d211ee00-5543-4add-8f3a-79b1dc097866: HTTP 404
# Low audio features not found for track 'Rockstars' by Malik Harris in 2022.
# High audio features not found for track 'Rockstars' by Malik Harris in 2022.
# AcousticBrainz error for MBID low-level 12c096e5-32c5-4e68-a2b8-7278fe32b262: HTTP 404
# AcousticBrainz error for MBID high-level 12c096e5-32c5-4e68-a2b8-7278fe32b262: HTTP 404
# Low audio features not found for track 'Moth To A Flame' by Swedish House Mafia & The Weeknd in 2022.
# High audio features not found for track 'Moth To A Flame' by Swedish House Mafia & The Weeknd in 2022.
# AcousticBrainz error for MBID low-level d7b33c08-ecfa-4d5e-a6bb-656799886bf0: HTTP 404
# AcousticBrainz error for MBID high-level d7b33c08-ecfa-4d5e-a6bb-656799886bf0: HTTP 404
# Low audio features not found for track 'Letztes Mal' by Bonez MC & RAF Camora in 2022.
# High audio features not found for track 'Letztes Mal' by Bonez MC & RAF Camora in 2022.
# No MBID for track 'Sommer' by Bonez MC / RAF Camora in 2022.
# AcousticBrainz error for MBID low-level ead867f1-468d-403d-a745-5b614a43807a: HTTP 404
# AcousticBrainz error for MBID high-level ead867f1-468d-403d-a745-5b614a43807a: HTTP 404
# Low audio features not found for track 'Driving Home For Christmas' by Chris Rea in 2022.
# High audio features not found for track 'Driving Home For Christmas' by Chris Rea in 2022.
# Got low audio features for track 'Alright' by Alle Farben feat. Kiddo in 2022.
# Got high audio features for track 'Alright' by Alle Farben feat. Kiddo in 2022.
# AcousticBrainz error for MBID low-level c9fd5dc6-b9fa-44a9-99f2-c9df0d68d99c: HTTP 404
# AcousticBrainz error for MBID high-level c9fd5dc6-b9fa-44a9-99f2-c9df0d68d99c: HTTP 404
# Low audio features not found for track 'Anti-Hero' by Taylor Swift in 2022.
# High audio features not found for track 'Anti-Hero' by Taylor Swift in 2022.
# Combined results saved to 'tracks_audio_features_2016_2022.csv'.
